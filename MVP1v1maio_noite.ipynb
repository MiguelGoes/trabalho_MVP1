# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelGoes/trabalho_MVP1/blob/main/MVP1v1maio_noite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Definição da situação problema
#
# ---

# %% [markdown]
#  1° trabalho:
#   MVP:Analise de dados de um dataset para pré-processamento dos dados e apresentação das principais características.
#
#   Situação problema:
#
#  Gerente de uma corretora de ações deve orientar um cliente a investir em ações que apresente o maior retorno com o menor risco possível.
#
#  Método de análise:
#  Utilizando o histórico dos valores das ações negociadas na bolsa de valores do Brasil (B3) encontrar os papeis que apresente crescimento constante e sustentável ao longo dos anos.
# Dados: Utilizados:
# Ações Brasileiras entre 2018 e 2021. Preços de 376 ações contendo setores da Bolsa
#
# Link para acesso: https://www.kaggle.com/datasets/lucasprado/acoesbrasileiras2018a2021

# %% [markdown]
# #  Carregamento dos dados

# %% [markdown]
# 1° Passo: carregar a biblioteca pandas

# %%
# 1° passo: Importação da biblioteca pandas
import pandas as pd

# %% [markdown]
#  Depois de pesquisas em base de dados recomendadas durante as aulas, escolhi o dataset *Ações Brasileiras entre 2018 e 2021*, esse dataset contem valores das ações de empresas possuem capital aberto na Ibovespa (B3), . O dataset pode ser acessado pelo link:
#   https://www.kaggle.com/datasets/lucasprado/acoesbrasileiras2018a2021.
#   Por questão de praticidade o arquivo foi carregado no drive com o nome "acoes.xlsx"
#    Esse dataset possui os seguinte dados:
#
#     1- Preço da ação na abertura do pregão (Preco_abertura).
#     2- Maior preço que a ação alcançou (Maior_preco).
#     3- Menor preço que a ação alcançou (Menor_preco).
#     4- Preço da ação na fechamento do pregão (Preco_fechamento).
#     5- volume transacionado (volume).
#     6- Preço ajustado (Preco_ajustado).
#     7- Data de referência do dado (Data).
#     8- Código da empresa na bolsa de valores  (Ticker).
#     9- Variação do preço ajustado da ação entre o dia em analise e o dia anterior (Varia_ajustado_abertura).
#     10-  Variação do preço ajustado de fechamento da ação entre o dia em analise e o dia anterior (varia_ajustado_fecha).
#     11- Nome da empresa em analise (Nome).
#     12- Setor de atuação da empresa (Setor).
#     13- Subsetor de atuação da empresa (Subsetor).
#     14- Tipo da ação (Tipo) (1*BDR, 2*ORDINARIA, 3*PREFERENCIAL)
#     15 - classificação pelo o faturamento da empresa (Classificacao)(Mega cap, big cap, mid cap, small cap, micro cap, nano cap) .
#
#
#    1* Ações BDRs (Brazilian Depositary Receipts) são certificados representativos de ações de empresas estrangeiras, negociados no Brasil. Um programa de BDR é o instrumento ideal para empresas estrangeiras estabelecerem presença no mercado de capitais mais dinâmico da América Latina.
#
#    2* Ações ordinárias (ON) são aquelas que conferem direito a voto e participação nas decisões da companhia.
#
#    3* Ações preferenciais (PN) são as que têm preferência no recebimento de proventos, mas não dão direito ao voto.

# %% [markdown]
# Após a escolha do dataset realizei a importação e a nomeação dos atributos.

# %%
# importação dos dados utilizando que estão carregados no drive 
try:
    nomes_atributos =( ['Preco_abertura', 'Maior_preco', 'Menor_preco', 'Preco_fechamento', 'volume', 'Preco_ajustado',
                    'Data', 'Ticker', 'Varia_ajustado_abertura', 'varia_ajustado_fecha', 'Nome', 'Setor','Subsetor', 'Tipo', 
                    'Classificacao'])
    dados=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/ACOES.xlsx', names = nomes_atributos)
    print('Dados carregados com sucesso')
except:
    print('Erro ao carregar dados, verifique o formato e local do arquivo')
# Out:
# Dados carregados com sucesso

# %% [markdown]
# # Veriicação dos dados

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  Uma vez os dados carregados, uma verificação é realizada para conferir o nome e tipo do dado que está presente em cada coluna, assim evitando a utilização dos dados de maneira local errado.

# %%
from tabulate import tabulate

colunas = dados.columns
i=0
print('Nome das colunas\n')
print('Número da coluna     Nome da coluna              Tipo da variável dessa coluna')
for nomes in colunas:
  print('{:<20} {:<28} {}'. format(i+1, colunas[i], type(dados.dtypes[i])))
  i=i+1
# Out:
# Nome das colunas
#
# Número da coluna     Nome da coluna              Tipo da variável dessa coluna
# 1                    Preco_abertura               <class 'numpy.dtype[float64]'>
# 2                    Maior_preco                  <class 'numpy.dtype[float64]'>
# 3                    Menor_preco                  <class 'numpy.dtype[float64]'>
# 4                    Preco_fechamento             <class 'numpy.dtype[float64]'>
# 5                    volume                       <class 'numpy.dtype[int64]'>
# 6                    Preco_ajustado               <class 'numpy.dtype[float64]'>
# 7                    Data                         <class 'numpy.dtype[datetime64]'>
# 8                    Ticker                       <class 'numpy.dtype[object_]'>
# 9                    Varia_ajustado_abertura      <class 'numpy.dtype[float64]'>
# 10                   varia_ajustado_fecha         <class 'numpy.dtype[float64]'>
# 11                   Nome                         <class 'numpy.dtype[object_]'>
# 12                   Setor                        <class 'numpy.dtype[object_]'>
# 13                   Subsetor                     <class 'numpy.dtype[object_]'>
# 14                   Tipo                         <class 'numpy.dtype[object_]'>
# 15                   Classificacao                <class 'numpy.dtype[object_]'>

# %% [markdown]
#   Com os dados no formato esperado é também realizada a visualização das primeiras e das últimas linhas do dataset para verificar se existe algum equívoco na nomeação ou formato do dado.

# %%
dados.head(6)
# Out:
#    Preco_abertura  Maior_preco  Menor_preco  Preco_fechamento  volume  \
# 0           14.94        15.16        14.70             14.89   94500
# 1           14.89        15.32        14.79             14.96  584700
# 2           15.00        15.16        14.81             15.09  290100
# 3           15.05        15.17        14.95             15.05  131500
# 4           15.05        15.10        14.62             14.79  244500
# 5           14.87        14.87        14.50             14.65   64200
#
#    Preco_ajustado       Data    Ticker  Varia_ajustado_abertura  \
# 0           14.74 2018-01-02  AALR3.SA                      NaN
# 1           14.81 2018-01-03  AALR3.SA                 0.004701
# 2           14.94 2018-01-04  AALR3.SA                 0.008690
# 3           14.90 2018-01-05  AALR3.SA                -0.002651
# 4           14.64 2018-01-08  AALR3.SA                -0.017276
# 5           14.50 2018-01-09  AALR3.SA                -0.009466
#
#    varia_ajustado_fecha    Nome  Setor                 Subsetor       Tipo  \
# 0                   NaN  ALLIAR  Saúde  Análises e Diagnósticos  Ordinaria
# 1              0.004701  ALLIAR  Saúde  Análises e Diagnósticos  Ordinaria
# 2              0.008690  ALLIAR  Saúde  Análises e Diagnósticos  Ordinaria
# 3             -0.002651  ALLIAR  Saúde  Análises e Diagnósticos  Ordinaria
# 4             -0.017276  ALLIAR  Saúde  Análises e Diagnósticos  Ordinaria
# 5             -0.009466  ALLIAR  Saúde  Análises e Diagnósticos  Ordinaria
#
#   Classificacao
# 0     Small Cap
# 1     Small Cap
# 2     Small Cap
# 3     Small Cap
# 4     Small Cap
# 5     Small Cap

# %%
dados.tail(6)
# Out:
#         Preco_abertura  Maior_preco  Menor_preco  Preco_fechamento   volume  \
# 298855           27.37        27.65        26.85             27.00  2901800
# 298856           27.00        28.00        26.70             26.71  2806700
# 298857           26.81        27.73        26.26             27.73  2433000
# 298858           27.64        27.75        26.60             27.09  1801000
# 298859           26.89        27.24        26.43             26.71  1223600
# 298860           26.66        28.30        26.55             28.04  2396200
#
#         Preco_ajustado       Data    Ticker  Varia_ajustado_abertura  \
# 298855           27.00 2021-03-23  YDUQ3.SA                -0.023861
# 298856           26.71 2021-03-24  YDUQ3.SA                -0.010741
# 298857           27.73 2021-03-25  YDUQ3.SA                 0.038188
# 298858           27.09 2021-03-26  YDUQ3.SA                -0.023080
# 298859           26.71 2021-03-29  YDUQ3.SA                -0.014027
# 298860           28.04 2021-03-30  YDUQ3.SA                 0.049794
#
#         varia_ajustado_fecha        Nome            Setor  Subsetor  \
# 298855             -0.023861  YDUQS PART  Consumo Cíclico  Diversos
# 298856             -0.010741  YDUQS PART  Consumo Cíclico  Diversos
# 298857              0.038188  YDUQS PART  Consumo Cíclico  Diversos
# 298858             -0.023080  YDUQS PART  Consumo Cíclico  Diversos
# 298859             -0.014027  YDUQS PART  Consumo Cíclico  Diversos
# 298860              0.049794  YDUQS PART  Consumo Cíclico  Diversos
#
#              Tipo Classificacao
# 298855  Ordinaria       Mid Cap
# 298856  Ordinaria       Mid Cap
# 298857  Ordinaria       Mid Cap
# 298858  Ordinaria       Mid Cap
# 298859  Ordinaria       Mid Cap
# 298860  Ordinaria       Mid Cap

# %% [markdown]
# Agora começaremos a realizar as primeiras analises dos dados. Verificado se todos os dados foram carregados, para isso conferimos a quantidade de linhas em cada coluna do dataset.

# %%
quant = dados.count()
print('Quantidade de dado de cada coluna \n\n{}'.format(quant))
print('Formato dos dados {}'.format(dados.shape))
# Out:
# Quantidade de dado de cada coluna
#
# Preco_abertura             298861
# Maior_preco                298861
# Menor_preco                298861
# Preco_fechamento           298861
# volume                     298861
# Preco_ajustado             298861
# Data                       298861
# Ticker                     298861
# Varia_ajustado_abertura    298486
# varia_ajustado_fecha       298486
# Nome                       298861
# Setor                      298861
# Subsetor                   298861
# Tipo                       298861
# Classificacao              298861
# dtype: int64
# Formato dos dados (298861, 15)

# %% [markdown]
# # Tratando dados faltantes

# %% [markdown]
#  Ao verificar o resultado acima é possível perceber que nos campos " varia_ajustado_abertura" e varia_ajustado_fecha"  o número de linhas está diferente dos demais. Vamos verificar se nessas variais existem dados faltantes.

# %%
import missingno as msno
msno.bar(dados);
dados.isnull().sum().sort_values(ascending=False)
# Out:
# Varia_ajustado_abertura    375
# varia_ajustado_fecha       375
# Preco_abertura               0
# Maior_preco                  0
# Menor_preco                  0
# Preco_fechamento             0
# volume                       0
# Preco_ajustado               0
# Data                         0
# Ticker                       0
# Nome                         0
# Setor                        0
# Subsetor                     0
# Tipo                         0
# Classificacao                0
# dtype: int64

# %% [markdown]
#  Como suspetado nos dois campos existem 375 valores faltantes.
#  Vamos verificar em quais linhas esses valores estão.

# %%
a = dados[dados.isnull().any(axis=1)]
print(a)
print(a.iloc[0, 0])
# Out:
#         Preco_abertura  Maior_preco  Menor_preco  Preco_fechamento    volume  \
# 0                14.94        15.16        14.70             14.89     94500
# 797              16.71        16.73        16.44             16.46    328681
# 1594             21.33        21.75        21.17             21.69  12717900
# 2391              4.98         4.98         4.98              4.98      1000
# 3188             12.45        12.80        12.40             12.67     39100
# ...                ...          ...          ...               ...       ...
# 294876           11.79        12.46        11.79             12.15    566200
# 295673            7.40         7.40         7.40              7.40         0
# 296470            5.25         5.25         5.00              5.01      3800
# 297267           40.00        40.00        40.00             40.00         0
# 298064           32.65        34.09        32.65             33.87   2677200
#
#         Preco_ajustado       Data     Ticker  Varia_ajustado_abertura  \
# 0                14.74 2018-01-02   AALR3.SA                      NaN
# 797              13.89 2018-01-02   ABCB4.SA                      NaN
# 1594             19.84 2018-01-02   ABEV3.SA                      NaN
# 2391              4.39 2018-01-02   AFLT3.SA                      NaN
# 3188             11.01 2018-01-02   AGRO3.SA                      NaN
# ...                ...        ...        ...                      ...
# 294876            9.25 2018-01-02   WIZS3.SA                      NaN
# 295673            6.94 2018-01-02   WLMM3.SA                      NaN
# 296470            4.81 2018-01-02   WLMM4.SA                      NaN
# 297267           31.84 2018-01-02  WSON33.SA                      NaN
# 298064           30.47 2018-01-02   YDUQ3.SA                      NaN
#
#         varia_ajustado_fecha         Nome                Setor  \
# 0                        NaN       ALLIAR                Saúde
# 797                      NaN   ABC BRASIL           Financeiro
# 1594                     NaN    AMBEV S/A  Consumo não Cíclico
# 2391                     NaN   AFLUENTE T    Utilidade Pública
# 3188                     NaN   BRASILAGRO  Consumo não Cíclico
# ...                      ...          ...                  ...
# 294876                   NaN     WIZ S.A.           Financeiro
# 295673                   NaN  WLM IND COM     Bens Industriais
# 296470                   NaN  WLM IND COM     Bens Industriais
# 297267                   NaN  WILSON SONS     Bens Industriais
# 298064                   NaN   YDUQS PART      Consumo Cíclico
#
#                           Subsetor          Tipo Classificacao
# 0          Análises e Diagnósticos     Ordinaria     Small Cap
# 797     Intermediários Financeiros  Preferencial     Small Cap
# 1594                       Bebidas     Ordinaria      Mega Cap
# 2391             Utilidade Pública     Ordinaria     Micro Cap
# 3188                  Agropecuária     Ordinaria     Small Cap
# ...                            ...           ...           ...
# 294876       Previdência e Seguros     Ordinaria     Small Cap
# 295673                    Comércio     Ordinaria     Micro Cap
# 296470                    Comércio  Preferencial     Micro Cap
# 297267                  Transporte     Ordinaria             -
# 298064                    Diversos     Ordinaria       Mid Cap
#
# [375 rows x 15 columns]
# 14.94

# %% [markdown]
#   Verificando quantas ações diferentes são negociadas na bolsa temos o seguinte número.

# %%
num_empresas=dados['Ticker'].nunique()
print ('Número de ações negociadas na bolsa de valores é {}'.format(num_empresas))
# Out:
# Número de ações negociadas na bolsa de valores é 375

# %% [markdown]
#  Como o número de ações é o mesmo de itens faltantes a possível falta de valores pode ser devido a forma de calcular esses valores.
#  Os valores de "Varia_ajustado_abertura" e " varia_ajustado_fecha " são caculados com base no valor de "Preco_ajustado" e "Preco_fechamento" do dia atual e do dia anterior, como não existe valor coletado antes do dia 2 de janeiro de 2018 esses valores não podem ser computados, por isso essas linhas serão excluidas.
#
# ![image.png](data:image/png;base64,...)

# %%
dados=dados.dropna()

# %% [markdown]
#  Verificando se as linhas com dados nulos foram excluidas

# %%
msno.bar(dados);
dados.isnull().sum().sort_values(ascending=False)
# Out:
# Preco_abertura             0
# Maior_preco                0
# Menor_preco                0
# Preco_fechamento           0
# volume                     0
# Preco_ajustado             0
# Data                       0
# Ticker                     0
# Varia_ajustado_abertura    0
# varia_ajustado_fecha       0
# Nome                       0
# Setor                      0
# Subsetor                   0
# Tipo                       0
# Classificacao              0
# dtype: int64

# %% [markdown]
#  Agora o dataframe possuim 298486 linhas e não possui dados nulos.

# %% [markdown]
# # Interpretação dos dados

# %% [markdown]
#  Vamos coferir quantos setores e subsetores diferentes existem, depois verificamos quais são os setores e subsetores das empresas que são cotadas na bolsa de valores.

# %%
Quant_setor = dados['Setor'].nunique()
Quant_subsetor = dados['Subsetor'].nunique()
Nome_setores = dados['Setor'].unique()
print ('Quantidade de setores diferentes é {}'.format(Quant_setor))
print ('Quantidade de subsetores diferentes é {}\n'.format(Quant_subsetor))

print ('Os setores são:')
i = 1
for nomes in Nome_setores:
  print ('{} - {}'.format(i, nomes))
  i=i+1
# Out:
# Quantidade de setores diferentes é 11
# Quantidade de subsetores diferentes é 41
#
# Os setores são:
# 1 - Saúde
# 2 - Financeiro
# 3 - Consumo não Cíclico
# 4 - Utilidade Pública
# 5 - Consumo Cíclico
# 6 - Outros
# 7 - Bens Industriais
# 8 - Materiais Básicos
# 9 - Petróleo, Gás e Biocombustíveis
# 10 - Tecnologia da Informação
# 11 - Comunicações

# %% [markdown]
# Verificamos agora quantos dias foram realizados pregões, quantas empresas possuem ações negociadas na bolsa de valores e quantos tickers são negociados na bolsa.

# %%
pregao = float(dados['Data'].nunique())
print('Quantidade de pregões realizados no periodo {:.2f}'.format(pregao))
num_empresas=dados['Nome'].nunique()
print('Número total de empresas que possuem ações é {}'. format(num_empresas))
print('Número total de ações negociadas é {}'. format(dados['Ticker'].nunique()))
# Out:
# Quantidade de pregões realizados no periodo 834.00
# Número total de empresas que possuem ações é 283
# Número total de ações negociadas é 375

# %% [markdown]
#  Comparando os resultado obtido acima é possível perceber que existe empresas com mais de uma ação cotada na bolsa de valores.
#
#  Número total de ações > Número total de empresas.
#
#  Isso mostra que existe pelo menos uma empresa com mais de uma ação cotada.

# %% [markdown]
#   Agora será veriifcando qual foi o valor de abertura no primeiro e o último dia do registrado, verificando quanto foi o ganho nesse período,  e qual foi o valor médio de cada ticker.
#    Para facilitar a organizaçao os dados foram organizados em uma lista de dicionarios.

# %%
lista2 = []
i=0
val = dados['Ticker'].unique()

for i in range(len(val)) :
  dicio = {}
  
 # Área de coleta dos dados
  a = (dados[dados['Ticker']==val[i]])
  print(a.iloc[1, 7])
  datafin = str(a.iloc[(len(a))-1, 6])
  datain = str(a.iloc[0, 6])
  valor_aberinic = a.iloc[1, 1]
  valor_aberfin = a.iloc[len(a)-1,1]
  variacao = 100*(valor_aberfin-valor_aberinic)/valor_aberfin
  Setor = a.iloc[len(a)-1,11]
  Nome = a.iloc[len(a)-1,10]
 
  # Cálculo da média dos valores de abertura
  j = 0 
  media = 0
  soma = 0
  for j in range(len(a)):
     soma = soma + a.iloc[j, 1]
  media = soma/len(a)  

  # Área de impressão dos dados
  print('O Nome da empresa é {}'.format(Nome))
  print('A media do preço de abertura no periodo foi R$ {:.2f} '.format(media))
  print('valor na data {} foi de  R$ {:.2f}'. format(datain[:-8], valor_aberinic))
  print('valor na data {} foi de R$ {:.2f} '. format(datafin[:-8], valor_aberfin))
  print('A variação do preço no periodo foi {:.2f}% foi de R$ {} '. format(variacao, datafin[:-8]))
  print('O setor da empresa é {}\n\n'.format(Setor))
  dicio = {'ticker':a.iloc[1, 7],'Nome':a.iloc[1, 10], 'media': media, 'valor_aber_ini':valor_aberinic, 'valor_aber_final': valor_aberfin, 'variacao': variacao, 'Setor': Setor} 
  lista2.append(dicio)
i=+i
# Out:
# AALR3.SA
# O Nome da empresa é ALLIAR
# A media do preço de abertura no periodo foi R$ 14.05
# valor na data 2018-01-03  foi de  R$ 15.16
# valor na data 2021-03-30  foi de R$ 9.03
# A variação do preço no periodo foi -67.88% foi de R$ 2021-03-30
# O setor da empresa é Saúde
#
#
# ABCB4.SA
# O Nome da empresa é ABC BRASIL
# A media do preço de abertura no periodo foi R$ 16.83
# valor na data 2018-01-03  foi de  R$ 16.62
# valor na data 2021-03-30  foi de R$ 14.95
# A variação do preço no periodo foi -11.17% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# ABEV3.SA
# O Nome da empresa é AMBEV S/A
# A media do preço de abertura no periodo foi R$ 17.39
# valor na data 2018-01-03  foi de  R$ 21.82
# valor na data 2021-03-30  foi de R$ 15.73
# A variação do preço no periodo foi -38.72% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# AFLT3.SA
# O Nome da empresa é AFLUENTE T
# A media do preço de abertura no periodo foi R$ 8.16
# valor na data 2018-01-03  foi de  R$ 4.98
# valor na data 2021-03-30  foi de R$ 9.20
# A variação do preço no periodo foi 45.87% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# AGRO3.SA
# O Nome da empresa é BRASILAGRO
# A media do preço de abertura no periodo foi R$ 17.84
# valor na data 2018-01-03  foi de  R$ 13.10
# valor na data 2021-03-30  foi de R$ 22.20
# A variação do preço no periodo foi 40.99% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# AHEB3.SA
# O Nome da empresa é SPTURIS
# A media do preço de abertura no periodo foi R$ 55.65
# valor na data 2018-01-03  foi de  R$ 100.61
# valor na data 2021-03-30  foi de R$ 21.90
# A variação do preço no periodo foi -359.41% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# ALPA3.SA
# O Nome da empresa é ALPARGATAS
# A media do preço de abertura no periodo foi R$ 21.23
# valor na data 2018-01-03  foi de  R$ 13.68
# valor na data 2021-03-30  foi de R$ 32.80
# A variação do preço no periodo foi 58.29% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# ALPA4.SA
# O Nome da empresa é ALPARGATAS
# A media do preço de abertura no periodo foi R$ 23.59
# valor na data 2018-01-03  foi de  R$ 13.96
# valor na data 2021-03-30  foi de R$ 38.13
# A variação do preço no periodo foi 63.39% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# ALSO3.SA
# O Nome da empresa é ALIANSCSONAE
# A media do preço de abertura no periodo foi R$ 29.66
# valor na data 2018-01-03  foi de  R$ 25.86
# valor na data 2021-03-30  foi de R$ 28.05
# A variação do preço no periodo foi 7.81% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# ALUP3.SA
# O Nome da empresa é ALUPAR
# A media do preço de abertura no periodo foi R$ 8.80
# valor na data 2018-01-03  foi de  R$ 8.00
# valor na data 2021-03-30  foi de R$ 8.78
# A variação do preço no periodo foi 8.88% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ALUP4.SA
# O Nome da empresa é ALUPAR
# A media do preço de abertura no periodo foi R$ 6.93
# valor na data 2018-01-03  foi de  R$ 5.35
# valor na data 2021-03-30  foi de R$ 8.60
# A variação do preço no periodo foi 37.79% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ALUP11.SA
# O Nome da empresa é ALUPAR
# A media do preço de abertura no periodo foi R$ 22.48
# valor na data 2018-01-03  foi de  R$ 18.45
# valor na data 2021-03-30  foi de R$ 25.73
# A variação do preço no periodo foi 28.29% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# AMAR3.SA
# O Nome da empresa é LOJAS MARISA
# A media do preço de abertura no periodo foi R$ 7.40
# valor na data 2018-01-03  foi de  R$ 8.75
# valor na data 2021-03-30  foi de R$ 5.55
# A variação do preço no periodo foi -57.66% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# ANIM3.SA
# O Nome da empresa é ANIMA
# A media do preço de abertura no periodo foi R$ 7.92
# valor na data 2018-01-03  foi de  R$ 9.73
# valor na data 2021-03-30  foi de R$ 9.59
# A variação do preço no periodo foi -1.46% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# APER3.SA
# O Nome da empresa é ALPER S.A.
# A media do preço de abertura no periodo foi R$ 23.16
# valor na data 2018-01-03  foi de  R$ 11.56
# valor na data 2021-03-30  foi de R$ 51.16
# A variação do preço no periodo foi 77.40% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# ARZZ3.SA
# O Nome da empresa é AREZZO CO
# A media do preço de abertura no periodo foi R$ 54.01
# valor na data 2018-01-03  foi de  R$ 60.91
# valor na data 2021-03-30  foi de R$ 70.84
# A variação do preço no periodo foi 14.02% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# ATOM3.SA
# O Nome da empresa é ATOMPAR
# A media do preço de abertura no periodo foi R$ 2.46
# valor na data 2018-01-03  foi de  R$ 3.45
# valor na data 2021-03-30  foi de R$ 3.85
# A variação do preço no periodo foi 10.39% foi de R$ 2021-03-30
# O setor da empresa é Outros
#
#
# AZEV3.SA
# O Nome da empresa é AZEVEDO
# A media do preço de abertura no periodo foi R$ 6.66
# valor na data 2018-01-03  foi de  R$ 5.55
# valor na data 2021-03-30  foi de R$ 6.16
# A variação do preço no periodo foi 9.90% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# AZEV4.SA
# O Nome da empresa é AZEVEDO
# A media do preço de abertura no periodo foi R$ 3.53
# valor na data 2018-01-03  foi de  R$ 3.94
# valor na data 2021-03-30  foi de R$ 3.98
# A variação do preço no periodo foi 1.01% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# AZUL4.SA
# O Nome da empresa é AZUL
# A media do preço de abertura no periodo foi R$ 35.50
# valor na data 2018-01-03  foi de  R$ 27.47
# valor na data 2021-03-30  foi de R$ 39.25
# A variação do preço no periodo foi 30.01% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# B3SA3.SA
# O Nome da empresa é B3
# A media do preço de abertura no periodo foi R$ 40.40
# valor na data 2018-01-03  foi de  R$ 23.60
# valor na data 2021-03-30  foi de R$ 54.39
# A variação do preço no periodo foi 56.61% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BAHI3.SA
# O Nome da empresa é BAHEMA
# A media do preço de abertura no periodo foi R$ 90.87
# valor na data 2018-01-03  foi de  R$ 53.16
# valor na data 2021-03-30  foi de R$ 70.50
# A variação do preço no periodo foi 24.60% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# BALM3.SA
# O Nome da empresa é BAUMER
# A media do preço de abertura no periodo foi R$ 12.57
# valor na data 2018-01-03  foi de  R$ 8.30
# valor na data 2021-03-30  foi de R$ 16.22
# A variação do preço no periodo foi 48.83% foi de R$ 2021-03-30
# O setor da empresa é Saúde
#
#
# BALM4.SA
# O Nome da empresa é BAUMER
# A media do preço de abertura no periodo foi R$ 11.94
# valor na data 2018-01-03  foi de  R$ 8.80
# valor na data 2021-03-30  foi de R$ 14.45
# A variação do preço no periodo foi 39.10% foi de R$ 2021-03-30
# O setor da empresa é Saúde
#
#
# BAUH3.SA
# O Nome da empresa é EXCELSIOR
# A media do preço de abertura no periodo foi R$ 5.00
# valor na data 2018-01-03  foi de  R$ 5.00
# valor na data 2021-03-30  foi de R$ 5.00
# A variação do preço no periodo foi 0.00% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# BAUH4.SA
# O Nome da empresa é EXCELSIOR
# A media do preço de abertura no periodo foi R$ 51.02
# valor na data 2018-01-03  foi de  R$ 12.36
# valor na data 2021-03-30  foi de R$ 95.00
# A variação do preço no periodo foi 86.99% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# BAZA3.SA
# O Nome da empresa é AMAZONIA
# A media do preço de abertura no periodo foi R$ 31.31
# valor na data 2018-01-03  foi de  R$ 25.69
# valor na data 2021-03-30  foi de R$ 40.19
# A variação do preço no periodo foi 36.08% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BBAS3.SA
# O Nome da empresa é BRASIL
# A media do preço de abertura no periodo foi R$ 40.31
# valor na data 2018-01-03  foi de  R$ 33.96
# valor na data 2021-03-30  foi de R$ 30.78
# A variação do preço no periodo foi -10.33% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BBDC3.SA
# O Nome da empresa é BRADESCO
# A media do preço de abertura no periodo foi R$ 24.44
# valor na data 2018-01-03  foi de  R$ 22.87
# valor na data 2021-03-30  foi de R$ 24.10
# A variação do preço no periodo foi 5.10% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BBDC4.SA
# O Nome da empresa é BRADESCO
# A media do preço de abertura no periodo foi R$ 26.94
# valor na data 2018-01-03  foi de  R$ 24.48
# valor na data 2021-03-30  foi de R$ 27.48
# A variação do preço no periodo foi 10.92% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BBRK3.SA
# O Nome da empresa é BR BROKERS
# A media do preço de abertura no periodo foi R$ 4.49
# valor na data 2018-01-03  foi de  R$ 9.80
# valor na data 2021-03-30  foi de R$ 1.88
# A variação do preço no periodo foi -421.28% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BBSE3.SA
# O Nome da empresa é BBSEGURIDADE
# A media do preço de abertura no periodo foi R$ 29.13
# valor na data 2018-01-03  foi de  R$ 28.98
# valor na data 2021-03-30  foi de R$ 24.96
# A variação do preço no periodo foi -16.11% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BDLL3.SA
# O Nome da empresa é BARDELLA
# A media do preço de abertura no periodo foi R$ 39.24
# valor na data 2018-01-03  foi de  R$ 51.00
# valor na data 2021-03-30  foi de R$ 8.30
# A variação do preço no periodo foi -514.46% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# BDLL4.SA
# O Nome da empresa é BARDELLA
# A media do preço de abertura no periodo foi R$ 14.21
# valor na data 2018-01-03  foi de  R$ 29.00
# valor na data 2021-03-30  foi de R$ 9.25
# A variação do preço no periodo foi -213.51% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# BEEF3.SA
# O Nome da empresa é MINERVA
# A media do preço de abertura no periodo foi R$ 9.36
# valor na data 2018-01-03  foi de  R$ 10.72
# valor na data 2021-03-30  foi de R$ 10.62
# A variação do preço no periodo foi -0.94% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# BEES3.SA
# O Nome da empresa é BANESTES
# A media do preço de abertura no periodo foi R$ 5.05
# valor na data 2018-01-03  foi de  R$ 3.70
# valor na data 2021-03-30  foi de R$ 4.94
# A variação do preço no periodo foi 25.10% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BEES4.SA
# O Nome da empresa é BANESTES
# A media do preço de abertura no periodo foi R$ 5.25
# valor na data 2018-01-03  foi de  R$ 3.79
# valor na data 2021-03-30  foi de R$ 5.94
# A variação do preço no periodo foi 36.20% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BGIP3.SA
# O Nome da empresa é BANESE
# A media do preço de abertura no periodo foi R$ 42.43
# valor na data 2018-01-03  foi de  R$ 38.60
# valor na data 2021-03-30  foi de R$ 39.00
# A variação do preço no periodo foi 1.03% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BGIP4.SA
# O Nome da empresa é BANESE
# A media do preço de abertura no periodo foi R$ 34.17
# valor na data 2018-01-03  foi de  R$ 38.56
# valor na data 2021-03-30  foi de R$ 21.92
# A variação do preço no periodo foi -75.91% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BIDI4.SA
# O Nome da empresa é BANCO INTER
# A media do preço de abertura no periodo foi R$ 16.13
# valor na data 2018-05-03  foi de  R$ 74.89
# valor na data 2021-03-30  foi de R$ 52.14
# A variação do preço no periodo foi -43.63% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BIOM3.SA
# O Nome da empresa é BIOMM
# A media do preço de abertura no periodo foi R$ 11.00
# valor na data 2018-01-03  foi de  R$ 8.68
# valor na data 2021-03-30  foi de R$ 16.70
# A variação do preço no periodo foi 48.02% foi de R$ 2021-03-30
# O setor da empresa é Saúde
#
#
# BKBR3.SA
# O Nome da empresa é BK BRASIL
# A media do preço de abertura no periodo foi R$ 15.89
# valor na data 2018-01-03  foi de  R$ 17.95
# valor na data 2021-03-30  foi de R$ 9.80
# A variação do preço no periodo foi -83.16% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# BMEB3.SA
# O Nome da empresa é MERC BRASIL
# A media do preço de abertura no periodo foi R$ 11.31
# valor na data 2018-01-03  foi de  R$ 7.00
# valor na data 2021-03-30  foi de R$ 19.68
# A variação do preço no periodo foi 64.43% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BMEB4.SA
# O Nome da empresa é MERC BRASIL
# A media do preço de abertura no periodo foi R$ 10.56
# valor na data 2018-01-03  foi de  R$ 5.09
# valor na data 2021-03-30  foi de R$ 17.85
# A variação do preço no periodo foi 71.48% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BMIN3.SA
# O Nome da empresa é MERC INVEST
# A media do preço de abertura no periodo foi R$ 21.82
# valor na data 2018-01-03  foi de  R$ 37.00
# valor na data 2021-03-30  foi de R$ 22.32
# A variação do preço no periodo foi -65.77% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BMIN4.SA
# O Nome da empresa é MERC INVEST
# A media do preço de abertura no periodo foi R$ 17.40
# valor na data 2018-01-03  foi de  R$ 20.99
# valor na data 2021-03-30  foi de R$ 21.20
# A variação do preço no periodo foi 0.99% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BMKS3.SA
# O Nome da empresa é BIC MONARK
# A media do preço de abertura no periodo foi R$ 265.47
# valor na data 2018-01-03  foi de  R$ 350.00
# valor na data 2021-03-30  foi de R$ 242.24
# A variação do preço no periodo foi -44.48% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# BNBR3.SA
# O Nome da empresa é NORD BRASIL
# A media do preço de abertura no periodo foi R$ 60.74
# valor na data 2018-01-03  foi de  R$ 37.00
# valor na data 2021-03-30  foi de R$ 70.50
# A variação do preço no periodo foi 47.52% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BOBR4.SA
# O Nome da empresa é BOMBRIL
# A media do preço de abertura no periodo foi R$ 2.70
# valor na data 2018-01-03  foi de  R$ 4.98
# valor na data 2021-03-30  foi de R$ 2.72
# A variação do preço no periodo foi -83.09% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# BPAC3.SA
# O Nome da empresa é BTGP BANCO
# A media do preço de abertura no periodo foi R$ 24.29
# valor na data 2018-01-03  foi de  R$ 8.85
# valor na data 2021-03-30  foi de R$ 46.30
# A variação do preço no periodo foi 80.89% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BPAC11.SA
# O Nome da empresa é BTGP BANCO
# A media do preço de abertura no periodo foi R$ 51.33
# valor na data 2018-01-03  foi de  R$ 19.40
# valor na data 2021-03-30  foi de R$ 98.02
# A variação do preço no periodo foi 80.21% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BPAN4.SA
# O Nome da empresa é BANCO PAN
# A media do preço de abertura no periodo foi R$ 12.47
# valor na data 2018-01-03  foi de  R$ 1.94
# valor na data 2021-03-30  foi de R$ 10.94
# A variação do preço no periodo foi 82.27% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BPHA3.SA
# O Nome da empresa é BR PHARMA
# A media do preço de abertura no periodo foi R$ 1.12
# valor na data 2018-01-03  foi de  R$ 3.75
# valor na data 2021-03-30  foi de R$ 0.62
# A variação do preço no periodo foi -504.84% foi de R$ 2021-03-30
# O setor da empresa é Saúde
#
#
# BRAP3.SA
# O Nome da empresa é BRADESPAR
# A media do preço de abertura no periodo foi R$ 33.59
# valor na data 2018-01-03  foi de  R$ 27.00
# valor na data 2021-03-30  foi de R$ 59.51
# A variação do preço no periodo foi 54.63% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# BRAP4.SA
# O Nome da empresa é BRADESPAR
# A media do preço de abertura no periodo foi R$ 37.82
# valor na data 2018-01-03  foi de  R$ 31.43
# valor na data 2021-03-30  foi de R$ 68.76
# A variação do preço no periodo foi 54.29% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# BRDT3.SA
# O Nome da empresa é PETROBRAS BR
# A media do preço de abertura no periodo foi R$ 23.59
# valor na data 2018-03-15  foi de  R$ 22.99
# valor na data 2021-03-30  foi de R$ 22.50
# A variação do preço no periodo foi -2.18% foi de R$ 2021-03-30
# O setor da empresa é Petróleo, Gás e Biocombustíveis
#
#
# BRFS3.SA
# O Nome da empresa é BRF SA
# A media do preço de abertura no periodo foi R$ 26.06
# valor na data 2018-01-03  foi de  R$ 37.80
# valor na data 2021-03-30  foi de R$ 25.48
# A variação do preço no periodo foi -48.35% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# BRGE3.SA
# O Nome da empresa é ALFA CONSORC
# A media do preço de abertura no periodo foi R$ 6.58
# valor na data 2018-01-03  foi de  R$ 3.53
# valor na data 2021-03-30  foi de R$ 9.18
# A variação do preço no periodo foi 61.55% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BRGE12.SA
# O Nome da empresa é ALFA CONSORC
# A media do preço de abertura no periodo foi R$ 4.50
# valor na data 2018-01-03  foi de  R$ 2.76
# valor na data 2021-03-30  foi de R$ 6.18
# A variação do preço no periodo foi 55.34% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BRGE11.SA
# O Nome da empresa é ALFA CONSORC
# A media do preço de abertura no periodo foi R$ 7.51
# valor na data 2018-01-03  foi de  R$ 4.38
# valor na data 2021-03-30  foi de R$ 10.00
# A variação do preço no periodo foi 56.20% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BRIV3.SA
# O Nome da empresa é ALFA INVEST
# A media do preço de abertura no periodo foi R$ 7.31
# valor na data 2018-01-03  foi de  R$ 5.80
# valor na data 2021-03-30  foi de R$ 9.26
# A variação do preço no periodo foi 37.37% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BRIV4.SA
# O Nome da empresa é ALFA INVEST
# A media do preço de abertura no periodo foi R$ 7.58
# valor na data 2018-01-03  foi de  R$ 6.50
# valor na data 2021-03-30  foi de R$ 8.68
# A variação do preço no periodo foi 25.12% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BRKM3.SA
# O Nome da empresa é BRASKEM
# A media do preço de abertura no periodo foi R$ 37.69
# valor na data 2018-01-03  foi de  R$ 43.50
# valor na data 2021-03-30  foi de R$ 38.10
# A variação do preço no periodo foi -14.17% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# BRML3.SA
# O Nome da empresa é BR MALLS PAR
# A media do preço de abertura no periodo foi R$ 12.17
# valor na data 2018-01-03  foi de  R$ 12.64
# valor na data 2021-03-30  foi de R$ 10.32
# A variação do preço no periodo foi -22.48% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BRPR3.SA
# O Nome da empresa é BR PROPERT
# A media do preço de abertura no periodo foi R$ 9.92
# valor na data 2018-01-03  foi de  R$ 11.09
# valor na data 2021-03-30  foi de R$ 8.83
# A variação do preço no periodo foi -25.59% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BRSR3.SA
# O Nome da empresa é BANRISUL
# A media do preço de abertura no periodo foi R$ 19.92
# valor na data 2018-01-03  foi de  R$ 24.00
# valor na data 2021-03-30  foi de R$ 13.95
# A variação do preço no periodo foi -72.04% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BSEV3.SA
# O Nome da empresa é BIOSEV
# A media do preço de abertura no periodo foi R$ 3.91
# valor na data 2018-01-03  foi de  R$ 4.98
# valor na data 2021-03-30  foi de R$ 7.73
# A variação do preço no periodo foi 35.58% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# BSLI3.SA
# O Nome da empresa é BRB BANCO
# A media do preço de abertura no periodo foi R$ 11.57
# valor na data 2018-01-03  foi de  R$ 3.50
# valor na data 2021-03-30  foi de R$ 49.12
# A variação do preço no periodo foi 92.87% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BSLI4.SA
# O Nome da empresa é BRB BANCO
# A media do preço de abertura no periodo foi R$ 8.71
# valor na data 2018-01-03  foi de  R$ 3.11
# valor na data 2021-03-30  foi de R$ 34.98
# A variação do preço no periodo foi 91.11% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# BTOW3.SA
# O Nome da empresa é B2W DIGITAL
# A media do preço de abertura no periodo foi R$ 55.54
# valor na data 2018-01-03  foi de  R$ 20.31
# valor na data 2021-03-30  foi de R$ 62.12
# A variação do preço no periodo foi 67.31% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# BTTL3.SA
# O Nome da empresa é BATTISTELLA
# A media do preço de abertura no periodo foi R$ 5.91
# valor na data 2018-01-03  foi de  R$ 3.99
# valor na data 2021-03-30  foi de R$ 10.86
# A variação do preço no periodo foi 63.26% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# CALI3.SA
# O Nome da empresa é CONST A LIND
# A media do preço de abertura no periodo foi R$ 105.21
# valor na data 2018-01-03  foi de  R$ 126.01
# valor na data 2021-03-30  foi de R$ 98.18
# A variação do preço no periodo foi -28.35% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CALI4.SA
# O Nome da empresa é CONST A LIND
# A media do preço de abertura no periodo foi R$ 67.97
# valor na data 2018-01-03  foi de  R$ 100.00
# valor na data 2021-03-30  foi de R$ 50.00
# A variação do preço no periodo foi -100.00% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CAML3.SA
# O Nome da empresa é CAMIL
# A media do preço de abertura no periodo foi R$ 8.68
# valor na data 2018-01-03  foi de  R$ 8.14
# valor na data 2021-03-30  foi de R$ 10.32
# A variação do preço no periodo foi 21.12% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# CARD3.SA
# O Nome da empresa é CSU CARDSYST
# A media do preço de abertura no periodo foi R$ 10.09
# valor na data 2018-01-03  foi de  R$ 10.71
# valor na data 2021-03-30  foi de R$ 17.41
# A variação do preço no periodo foi 38.48% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# CASN3.SA
# O Nome da empresa é CASAN
# A media do preço de abertura no periodo foi R$ 12.93
# valor na data 2018-01-03  foi de  R$ 8.00
# valor na data 2021-03-30  foi de R$ 14.35
# A variação do preço no periodo foi 44.25% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CASN4.SA
# O Nome da empresa é CASAN
# A media do preço de abertura no periodo foi R$ 11.11
# valor na data 2018-01-03  foi de  R$ 13.80
# valor na data 2021-03-30  foi de R$ 8.94
# A variação do preço no periodo foi -54.36% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CBEE3.SA
# O Nome da empresa é AMPLA ENERG
# A media do preço de abertura no periodo foi R$ 19.98
# valor na data 2018-01-03  foi de  R$ 26.44
# valor na data 2021-03-30  foi de R$ 16.09
# A variação do preço no periodo foi -64.33% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CCPR3.SA
# O Nome da empresa é CYRE COM-CCP
# A media do preço de abertura no periodo foi R$ 14.06
# valor na data 2018-01-03  foi de  R$ 11.00
# valor na data 2021-03-30  foi de R$ 11.83
# A variação do preço no periodo foi 7.02% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# CCRO3.SA
# O Nome da empresa é CCR SA
# A media do preço de abertura no periodo foi R$ 13.67
# valor na data 2018-01-03  foi de  R$ 16.65
# valor na data 2021-03-30  foi de R$ 12.45
# A variação do preço no periodo foi -33.73% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# CEBR3.SA
# O Nome da empresa é CEB
# A media do preço de abertura no periodo foi R$ 53.47
# valor na data 2018-01-03  foi de  R$ 26.00
# valor na data 2021-03-30  foi de R$ 185.00
# A variação do preço no periodo foi 85.95% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CEDO3.SA
# O Nome da empresa é CEDRO
# A media do preço de abertura no periodo foi R$ 9.18
# valor na data 2018-01-03  foi de  R$ 11.00
# valor na data 2021-03-30  foi de R$ 10.40
# A variação do preço no periodo foi -5.77% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CEDO4.SA
# O Nome da empresa é CEDRO
# A media do preço de abertura no periodo foi R$ 7.18
# valor na data 2018-01-03  foi de  R$ 6.82
# valor na data 2021-03-30  foi de R$ 5.58
# A variação do preço no periodo foi -22.22% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CEEB3.SA
# O Nome da empresa é COELBA
# A media do preço de abertura no periodo foi R$ 33.97
# valor na data 2018-01-03  foi de  R$ 23.90
# valor na data 2021-03-30  foi de R$ 41.00
# A variação do preço no periodo foi 41.71% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CEED3.SA
# O Nome da empresa é CEEE-D
# A media do preço de abertura no periodo foi R$ 64.68
# valor na data 2018-01-03  foi de  R$ 29.99
# valor na data 2021-03-30  foi de R$ 60.00
# A variação do preço no periodo foi 50.02% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CEED4.SA
# O Nome da empresa é CEEE-D
# A media do preço de abertura no periodo foi R$ 71.88
# valor na data 2018-01-03  foi de  R$ 33.00
# valor na data 2021-03-30  foi de R$ 70.00
# A variação do preço no periodo foi 52.86% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CEGR3.SA
# O Nome da empresa é CEG
# A media do preço de abertura no periodo foi R$ 46.25
# valor na data 2018-01-03  foi de  R$ 27.00
# valor na data 2021-03-30  foi de R$ 61.26
# A variação do preço no periodo foi 55.93% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CEPE3.SA
# O Nome da empresa é CELPE
# A media do preço de abertura no periodo foi R$ 31.97
# valor na data 2018-01-03  foi de  R$ 24.53
# valor na data 2021-03-30  foi de R$ 128.00
# A variação do preço no periodo foi 80.84% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CESP3.SA
# O Nome da empresa é CESP
# A media do preço de abertura no periodo foi R$ 24.27
# valor na data 2018-01-03  foi de  R$ 11.25
# valor na data 2021-03-30  foi de R$ 32.87
# A variação do preço no periodo foi 65.77% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CGAS3.SA
# O Nome da empresa é COMGAS
# A media do preço de abertura no periodo foi R$ 109.37
# valor na data 2018-01-03  foi de  R$ 59.48
# valor na data 2021-03-30  foi de R$ 150.00
# A variação do preço no periodo foi 60.35% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CGRA3.SA
# O Nome da empresa é GRAZZIOTIN
# A media do preço de abertura no periodo foi R$ 26.32
# valor na data 2018-01-03  foi de  R$ 27.98
# valor na data 2021-03-30  foi de R$ 31.00
# A variação do preço no periodo foi 9.74% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CGRA4.SA
# O Nome da empresa é GRAZZIOTIN
# A media do preço de abertura no periodo foi R$ 26.61
# valor na data 2018-01-03  foi de  R$ 27.69
# valor na data 2021-03-30  foi de R$ 30.65
# A variação do preço no periodo foi 9.66% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CIEL3.SA
# O Nome da empresa é CIELO
# A media do preço de abertura no periodo foi R$ 9.79
# valor na data 2018-01-03  foi de  R$ 24.75
# valor na data 2021-03-30  foi de R$ 3.60
# A variação do preço no periodo foi -587.50% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# CLSC3.SA
# O Nome da empresa é CELESC
# A media do preço de abertura no periodo foi R$ 48.17
# valor na data 2018-01-03  foi de  R$ 30.00
# valor na data 2021-03-30  foi de R$ 58.90
# A variação do preço no periodo foi 49.07% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CLSC4.SA
# O Nome da empresa é CELESC
# A media do preço de abertura no periodo foi R$ 44.88
# valor na data 2018-01-03  foi de  R$ 26.90
# valor na data 2021-03-30  foi de R$ 58.30
# A variação do preço no periodo foi 53.86% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CMIG3.SA
# O Nome da empresa é CEMIG
# A media do preço de abertura no periodo foi R$ 12.38
# valor na data 2018-01-03  foi de  R$ 6.38
# valor na data 2021-03-30  foi de R$ 15.69
# A variação do preço no periodo foi 59.34% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CMIG4.SA
# O Nome da empresa é CEMIG
# A media do preço de abertura no periodo foi R$ 11.37
# valor na data 2018-01-03  foi de  R$ 6.76
# valor na data 2021-03-30  foi de R$ 12.96
# A variação do preço no periodo foi 47.84% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# COCE3.SA
# O Nome da empresa é COELCE
# A media do preço de abertura no periodo foi R$ 51.89
# valor na data 2018-01-03  foi de  R$ 48.65
# valor na data 2021-03-30  foi de R$ 51.24
# A variação do preço no periodo foi 5.05% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# COGN3.SA
# O Nome da empresa é COGNA ON
# A media do preço de abertura no periodo foi R$ 9.73
# valor na data 2018-01-03  foi de  R$ 19.06
# valor na data 2021-03-30  foi de R$ 3.91
# A variação do preço no periodo foi -387.47% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CORR3.SA
# O Nome da empresa é COR RIBEIRO
# A media do preço de abertura no periodo foi R$ 12.00
# valor na data 2018-01-03  foi de  R$ 12.00
# valor na data 2021-03-30  foi de R$ 12.00
# A variação do preço no periodo foi 0.00% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# CORR4.SA
# O Nome da empresa é COR RIBEIRO
# A media do preço de abertura no periodo foi R$ 81.90
# valor na data 2018-01-03  foi de  R$ 145.00
# valor na data 2021-03-30  foi de R$ 82.00
# A variação do preço no periodo foi -76.83% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# CPFE3.SA
# O Nome da empresa é CPFL ENERGIA
# A media do preço de abertura no periodo foi R$ 29.16
# valor na data 2018-01-03  foi de  R$ 19.36
# valor na data 2021-03-30  foi de R$ 30.33
# A variação do preço no periodo foi 36.17% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CPLE3.SA
# O Nome da empresa é COPEL
# A media do preço de abertura no periodo foi R$ 4.60
# valor na data 2018-01-03  foi de  R$ 2.06
# valor na data 2021-03-30  foi de R$ 6.97
# A variação do preço no periodo foi 70.44% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CRDE3.SA
# O Nome da empresa é CR2
# A media do preço de abertura no periodo foi R$ 23.77
# valor na data 2018-01-03  foi de  R$ 30.40
# valor na data 2021-03-30  foi de R$ 23.50
# A variação do preço no periodo foi -29.36% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CRFB3.SA
# O Nome da empresa é CARREFOUR BR
# A media do preço de abertura no periodo foi R$ 19.21
# valor na data 2018-01-03  foi de  R$ 15.50
# valor na data 2021-03-30  foi de R$ 22.92
# A variação do preço no periodo foi 32.37% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# CRIV3.SA
# O Nome da empresa é ALFA FINANC
# A media do preço de abertura no periodo foi R$ 5.24
# valor na data 2018-01-03  foi de  R$ 3.45
# valor na data 2021-03-30  foi de R$ 5.24
# A variação do preço no periodo foi 34.16% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# CRIV4.SA
# O Nome da empresa é ALFA FINANC
# A media do preço de abertura no periodo foi R$ 6.06
# valor na data 2018-01-03  foi de  R$ 4.70
# valor na data 2021-03-30  foi de R$ 6.38
# A variação do preço no periodo foi 26.33% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# CRPG3.SA
# O Nome da empresa é CRISTAL
# A media do preço de abertura no periodo foi R$ 26.79
# valor na data 2018-01-03  foi de  R$ 16.16
# valor na data 2021-03-30  foi de R$ 51.00
# A variação do preço no periodo foi 68.31% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# CSAB3.SA
# O Nome da empresa é SEG AL BAHIA
# A media do preço de abertura no periodo foi R$ 48.61
# valor na data 2018-01-03  foi de  R$ 57.00
# valor na data 2021-03-30  foi de R$ 49.08
# A variação do preço no periodo foi -16.14% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# CSAB4.SA
# O Nome da empresa é SEG AL BAHIA
# A media do preço de abertura no periodo foi R$ 48.90
# valor na data 2018-01-03  foi de  R$ 56.02
# valor na data 2021-03-30  foi de R$ 50.99
# A variação do preço no periodo foi -9.86% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# CSAN3.SA
# O Nome da empresa é COSAN
# A media do preço de abertura no periodo foi R$ 56.54
# valor na data 2018-01-03  foi de  R$ 43.30
# valor na data 2021-03-30  foi de R$ 94.00
# A variação do preço no periodo foi 53.94% foi de R$ 2021-03-30
# O setor da empresa é Petróleo, Gás e Biocombustíveis
#
#
# CSMG3.SA
# O Nome da empresa é COPASA
# A media do preço de abertura no periodo foi R$ 18.22
# valor na data 2018-01-03  foi de  R$ 14.43
# valor na data 2021-03-30  foi de R$ 15.05
# A variação do preço no periodo foi 4.12% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CSNA3.SA
# O Nome da empresa é SID NACIONAL
# A media do preço de abertura no periodo foi R$ 14.45
# valor na data 2018-01-03  foi de  R$ 9.49
# valor na data 2021-03-30  foi de R$ 36.99
# A variação do preço no periodo foi 74.34% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# CSRN3.SA
# O Nome da empresa é COSERN
# A media do preço de abertura no periodo foi R$ 17.76
# valor na data 2018-01-03  foi de  R$ 18.30
# valor na data 2021-03-30  foi de R$ 15.17
# A variação do preço no periodo foi -20.63% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# CTKA3.SA
# O Nome da empresa é KARSTEN
# A media do preço de abertura no periodo foi R$ 10.44
# valor na data 2018-01-03  foi de  R$ 4.45
# valor na data 2021-03-30  foi de R$ 25.33
# A variação do preço no periodo foi 82.43% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CTKA4.SA
# O Nome da empresa é KARSTEN
# A media do preço de abertura no periodo foi R$ 8.99
# valor na data 2018-01-03  foi de  R$ 3.78
# valor na data 2021-03-30  foi de R$ 19.26
# A variação do preço no periodo foi 80.37% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CTNM3.SA
# O Nome da empresa é COTEMINAS
# A media do preço de abertura no periodo foi R$ 10.56
# valor na data 2018-01-03  foi de  R$ 7.90
# valor na data 2021-03-30  foi de R$ 12.00
# A variação do preço no periodo foi 34.17% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CTNM4.SA
# O Nome da empresa é COTEMINAS
# A media do preço de abertura no periodo foi R$ 7.81
# valor na data 2018-01-03  foi de  R$ 7.84
# valor na data 2021-03-30  foi de R$ 5.50
# A variação do preço no periodo foi -42.55% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CTSA3.SA
# O Nome da empresa é SANTANENSE
# A media do preço de abertura no periodo foi R$ 4.43
# valor na data 2018-01-03  foi de  R$ 3.76
# valor na data 2021-03-30  foi de R$ 2.75
# A variação do preço no periodo foi -36.73% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CTSA4.SA
# O Nome da empresa é SANTANENSE
# A media do preço de abertura no periodo foi R$ 2.03
# valor na data 2018-01-03  foi de  R$ 1.23
# valor na data 2021-03-30  foi de R$ 1.90
# A variação do preço no periodo foi 35.26% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CVCB3.SA
# O Nome da empresa é CVC BRASIL
# A media do preço de abertura no periodo foi R$ 40.23
# valor na data 2018-01-03  foi de  R$ 50.14
# valor na data 2021-03-30  foi de R$ 20.30
# A variação do preço no periodo foi -147.00% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# CYRE3.SA
# O Nome da empresa é CYRELA REALT
# A media do preço de abertura no periodo foi R$ 20.41
# valor na data 2018-01-03  foi de  R$ 13.65
# valor na data 2021-03-30  foi de R$ 24.64
# A variação do preço no periodo foi 44.60% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# DASA3.SA
# O Nome da empresa é DASA
# A media do preço de abertura no periodo foi R$ 50.25
# valor na data 2018-01-03  foi de  R$ 28.00
# valor na data 2021-03-30  foi de R$ 149.49
# A variação do preço no periodo foi 81.27% foi de R$ 2021-03-30
# O setor da empresa é Saúde
#
#
# DIRR3.SA
# O Nome da empresa é DIRECIONAL
# A media do preço de abertura no periodo foi R$ 10.67
# valor na data 2018-01-03  foi de  R$ 5.76
# valor na data 2021-03-30  foi de R$ 12.50
# A variação do preço no periodo foi 53.92% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# DMMO3.SA
# O Nome da empresa é DOMMO
# A media do preço de abertura no periodo foi R$ 6.91
# valor na data 2018-01-03  foi de  R$ 10.50
# valor na data 2021-03-30  foi de R$ 1.02
# A variação do preço no periodo foi -929.41% foi de R$ 2021-03-30
# O setor da empresa é Petróleo, Gás e Biocombustíveis
#
#
# DOHL3.SA
# O Nome da empresa é DOHLER
# A media do preço de abertura no periodo foi R$ 10.16
# valor na data 2018-01-03  foi de  R$ 6.00
# valor na data 2021-03-30  foi de R$ 27.67
# A variação do preço no periodo foi 78.32% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# DOHL4.SA
# O Nome da empresa é DOHLER
# A media do preço de abertura no periodo foi R$ 5.33
# valor na data 2018-01-03  foi de  R$ 4.80
# valor na data 2021-03-30  foi de R$ 5.65
# A variação do preço no periodo foi 15.04% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# DTCY3.SA
# O Nome da empresa é DTCOM-DIRECT
# A media do preço de abertura no periodo foi R$ 4.69
# valor na data 2018-01-03  foi de  R$ 3.40
# valor na data 2021-03-30  foi de R$ 10.30
# A variação do preço no periodo foi 66.99% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# DTEX3.SA
# O Nome da empresa é DURATEX
# A media do preço de abertura no periodo foi R$ 13.43
# valor na data 2018-01-03  foi de  R$ 9.87
# valor na data 2021-03-30  foi de R$ 18.88
# A variação do preço no periodo foi 47.72% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# EALT3.SA
# O Nome da empresa é ACO ALTONA
# A media do preço de abertura no periodo foi R$ 9.02
# valor na data 2018-01-03  foi de  R$ 2.30
# valor na data 2021-03-30  foi de R$ 16.19
# A variação do preço no periodo foi 85.79% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# EALT4.SA
# O Nome da empresa é ACO ALTONA
# A media do preço de abertura no periodo foi R$ 5.06
# valor na data 2018-01-03  foi de  R$ 3.50
# valor na data 2021-03-30  foi de R$ 5.14
# A variação do preço no periodo foi 31.91% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# ECOR3.SA
# O Nome da empresa é ECORODOVIAS
# A media do preço de abertura no periodo foi R$ 11.48
# valor na data 2018-01-03  foi de  R$ 13.07
# valor na data 2021-03-30  foi de R$ 11.56
# A variação do preço no periodo foi -13.06% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# ECPR3.SA
# O Nome da empresa é ENCORPAR
# A media do preço de abertura no periodo foi R$ 73.55
# valor na data 2018-01-03  foi de  R$ 33.00
# valor na data 2021-03-30  foi de R$ 77.00
# A variação do preço no periodo foi 57.14% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# ECPR4.SA
# O Nome da empresa é ENCORPAR
# A media do preço de abertura no periodo foi R$ 83.85
# valor na data 2018-01-03  foi de  R$ 39.87
# valor na data 2021-03-30  foi de R$ 74.96
# A variação do preço no periodo foi 46.81% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# EEEL3.SA
# O Nome da empresa é CEEE-GT
# A media do preço de abertura no periodo foi R$ 297.92
# valor na data 2018-01-03  foi de  R$ 165.00
# valor na data 2021-03-30  foi de R$ 547.50
# A variação do preço no periodo foi 69.86% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# EEEL4.SA
# O Nome da empresa é CEEE-GT
# A media do preço de abertura no periodo foi R$ 329.23
# valor na data 2018-01-03  foi de  R$ 160.00
# valor na data 2021-03-30  foi de R$ 600.00
# A variação do preço no periodo foi 73.33% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# EGIE3.SA
# O Nome da empresa é ENGIE BRASIL
# A media do preço de abertura no periodo foi R$ 40.08
# valor na data 2018-01-03  foi de  R$ 28.60
# valor na data 2021-03-30  foi de R$ 41.94
# A variação do preço no periodo foi 31.81% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# EKTR3.SA
# O Nome da empresa é ELEKTRO
# A media do preço de abertura no periodo foi R$ 21.14
# valor na data 2018-01-03  foi de  R$ 22.00
# valor na data 2021-03-30  foi de R$ 38.98
# A variação do preço no periodo foi 43.56% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# EKTR4.SA
# O Nome da empresa é ELEKTRO
# A media do preço de abertura no periodo foi R$ 20.62
# valor na data 2018-01-03  foi de  R$ 23.50
# valor na data 2021-03-30  foi de R$ 26.99
# A variação do preço no periodo foi 12.93% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ELET3.SA
# O Nome da empresa é ELETROBRAS
# A media do preço de abertura no periodo foi R$ 30.23
# valor na data 2018-01-03  foi de  R$ 18.67
# valor na data 2021-03-30  foi de R$ 33.28
# A variação do preço no periodo foi 43.90% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# EMAE4.SA
# O Nome da empresa é EMAE
# A media do preço de abertura no periodo foi R$ 26.45
# valor na data 2018-01-03  foi de  R$ 9.09
# valor na data 2021-03-30  foi de R$ 60.50
# A variação do preço no periodo foi 84.98% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# EMBR3.SA
# O Nome da empresa é EMBRAER
# A media do preço de abertura no periodo foi R$ 16.53
# valor na data 2018-01-03  foi de  R$ 22.20
# valor na data 2021-03-30  foi de R$ 14.40
# A variação do preço no periodo foi -54.17% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# ENAT3.SA
# O Nome da empresa é ENAUTA PART
# A media do preço de abertura no periodo foi R$ 12.53
# valor na data 2018-01-03  foi de  R$ 11.85
# valor na data 2021-03-30  foi de R$ 15.80
# A variação do preço no periodo foi 25.00% foi de R$ 2021-03-30
# O setor da empresa é Petróleo, Gás e Biocombustíveis
#
#
# ENBR3.SA
# O Nome da empresa é ENERGIAS BR
# A media do preço de abertura no periodo foi R$ 17.30
# valor na data 2018-01-03  foi de  R$ 13.72
# valor na data 2021-03-30  foi de R$ 19.90
# A variação do preço no periodo foi 31.06% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ENEV3.SA
# O Nome da empresa é ENEVA
# A media do preço de abertura no periodo foi R$ 7.89
# valor na data 2018-01-03  foi de  R$ 3.56
# valor na data 2021-03-30  foi de R$ 16.68
# A variação do preço no periodo foi 78.66% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ENGI3.SA
# O Nome da empresa é ENERGISA
# A media do preço de abertura no periodo foi R$ 12.47
# valor na data 2018-01-03  foi de  R$ 9.63
# valor na data 2021-03-30  foi de R$ 15.91
# A variação do preço no periodo foi 39.47% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ENGI4.SA
# O Nome da empresa é ENERGISA
# A media do preço de abertura no periodo foi R$ 7.50
# valor na data 2018-01-03  foi de  R$ 4.30
# valor na data 2021-03-30  foi de R$ 7.27
# A variação do preço no periodo foi 40.85% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ENGI11.SA
# O Nome da empresa é ENERGISA
# A media do preço de abertura no periodo foi R$ 42.32
# valor na data 2018-01-03  foi de  R$ 27.11
# valor na data 2021-03-30  foi de R$ 45.00
# A variação do preço no periodo foi 39.76% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ENMT3.SA
# O Nome da empresa é ENERGISA MT
# A media do preço de abertura no periodo foi R$ 24.60
# valor na data 2018-01-03  foi de  R$ 18.00
# valor na data 2021-03-30  foi de R$ 43.50
# A variação do preço no periodo foi 58.62% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ENMT4.SA
# O Nome da empresa é ENERGISA MT
# A media do preço de abertura no periodo foi R$ 24.43
# valor na data 2018-01-03  foi de  R$ 8.51
# valor na data 2021-03-30  foi de R$ 41.99
# A variação do preço no periodo foi 79.73% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# EQPA3.SA
# O Nome da empresa é EQTL PARA
# A media do preço de abertura no periodo foi R$ 2.77
# valor na data 2018-01-03  foi de  R$ 1.81
# valor na data 2021-03-30  foi de R$ 3.96
# A variação do preço no periodo foi 54.29% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# EQTL3.SA
# O Nome da empresa é EQUATORIAL
# A media do preço de abertura no periodo foi R$ 18.34
# valor na data 2018-01-03  foi de  R$ 13.16
# valor na data 2021-03-30  foi de R$ 22.98
# A variação do preço no periodo foi 42.73% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# ESTR4.SA
# O Nome da empresa é ESTRELA
# A media do preço de abertura no periodo foi R$ 22.78
# valor na data 2018-01-03  foi de  R$ 12.00
# valor na data 2021-03-30  foi de R$ 26.21
# A variação do preço no periodo foi 54.22% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# ETER3.SA
# O Nome da empresa é ETERNIT
# A media do preço de abertura no periodo foi R$ 5.02
# valor na data 2018-01-03  foi de  R$ 5.95
# valor na data 2021-03-30  foi de R$ 20.10
# A variação do preço no periodo foi 70.40% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# EUCA3.SA
# O Nome da empresa é EUCATEX
# A media do preço de abertura no periodo foi R$ 15.11
# valor na data 2018-01-03  foi de  R$ 6.99
# valor na data 2021-03-30  foi de R$ 23.35
# A variação do preço no periodo foi 70.06% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# EUCA4.SA
# O Nome da empresa é EUCATEX
# A media do preço de abertura no periodo foi R$ 5.45
# valor na data 2018-01-03  foi de  R$ 4.32
# valor na data 2021-03-30  foi de R$ 9.70
# A variação do preço no periodo foi 55.46% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# EVEN3.SA
# O Nome da empresa é EVEN
# A media do preço de abertura no periodo foi R$ 8.82
# valor na data 2018-01-03  foi de  R$ 6.00
# valor na data 2021-03-30  foi de R$ 10.43
# A variação do preço no periodo foi 42.47% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# EZTC3.SA
# O Nome da empresa é EZTEC
# A media do preço de abertura no periodo foi R$ 30.16
# valor na data 2018-01-03  foi de  R$ 18.50
# valor na data 2021-03-30  foi de R$ 32.43
# A variação do preço no periodo foi 42.95% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# FESA3.SA
# O Nome da empresa é FERBASA
# A media do preço de abertura no periodo foi R$ 27.96
# valor na data 2018-01-03  foi de  R$ 23.75
# valor na data 2021-03-30  foi de R$ 41.83
# A variação do preço no periodo foi 43.22% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# FESA4.SA
# O Nome da empresa é FERBASA
# A media do preço de abertura no periodo foi R$ 20.68
# valor na data 2018-01-03  foi de  R$ 25.00
# valor na data 2021-03-30  foi de R$ 35.64
# A variação do preço no periodo foi 29.85% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# FHER3.SA
# O Nome da empresa é FER HERINGER
# A media do preço de abertura no periodo foi R$ 3.53
# valor na data 2018-01-03  foi de  R$ 2.72
# valor na data 2021-03-30  foi de R$ 6.53
# A variação do preço no periodo foi 58.35% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# FIGE3.SA
# O Nome da empresa é INVEST BEMGE
# A media do preço de abertura no periodo foi R$ 43.00
# valor na data 2018-01-03  foi de  R$ 43.00
# valor na data 2021-03-30  foi de R$ 43.00
# A variação do preço no periodo foi 0.00% foi de R$ 2021-03-30
# O setor da empresa é Outros
#
#
# FIGE4.SA
# O Nome da empresa é INVEST BEMGE
# A media do preço de abertura no periodo foi R$ 38.01
# valor na data 2018-01-03  foi de  R$ 38.01
# valor na data 2021-03-30  foi de R$ 38.01
# A variação do preço no periodo foi 0.00% foi de R$ 2021-03-30
# O setor da empresa é Outros
#
#
# FLRY3.SA
# O Nome da empresa é FLEURY
# A media do preço de abertura no periodo foi R$ 25.39
# valor na data 2018-01-03  foi de  R$ 29.37
# valor na data 2021-03-30  foi de R$ 25.67
# A variação do preço no periodo foi -14.41% foi de R$ 2021-03-30
# O setor da empresa é Saúde
#
#
# FRAS3.SA
# O Nome da empresa é FRAS-LE
# A media do preço de abertura no periodo foi R$ 5.74
# valor na data 2018-01-03  foi de  R$ 5.79
# valor na data 2021-03-30  foi de R$ 12.20
# A variação do preço no periodo foi 52.54% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# FRIO3.SA
# O Nome da empresa é METALFRIO
# A media do preço de abertura no periodo foi R$ 61.85
# valor na data 2018-01-03  foi de  R$ 42.00
# valor na data 2021-03-30  foi de R$ 63.00
# A variação do preço no periodo foi 33.33% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# FRTA3.SA
# O Nome da empresa é POMIFRUTAS
# A media do preço de abertura no periodo foi R$ 6.27
# valor na data 2018-01-03  foi de  R$ 8.82
# valor na data 2021-03-30  foi de R$ 5.56
# A variação do preço no periodo foi -58.63% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# GEPA3.SA
# O Nome da empresa é GER PARANAP
# A media do preço de abertura no periodo foi R$ 38.78
# valor na data 2018-01-03  foi de  R$ 38.36
# valor na data 2021-03-30  foi de R$ 40.98
# A variação do preço no periodo foi 6.39% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# GEPA4.SA
# O Nome da empresa é GER PARANAP
# A media do preço de abertura no periodo foi R$ 42.86
# valor na data 2018-01-03  foi de  R$ 41.00
# valor na data 2021-03-30  foi de R$ 39.09
# A variação do preço no periodo foi -4.89% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# GFSA3.SA
# O Nome da empresa é GAFISA
# A media do preço de abertura no periodo foi R$ 8.02
# valor na data 2018-01-03  foi de  R$ 18.78
# valor na data 2021-03-30  foi de R$ 4.86
# A variação do preço no periodo foi -286.42% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# GGBR3.SA
# O Nome da empresa é GERDAU
# A media do preço de abertura no periodo foi R$ 14.21
# valor na data 2018-01-03  foi de  R$ 11.53
# valor na data 2021-03-30  foi de R$ 23.94
# ...
# valor na data 2018-01-03  foi de  R$ 5.07
# valor na data 2021-03-30  foi de R$ 14.74
# A variação do preço no periodo foi 65.60% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# SLCE3.SA
# O Nome da empresa é SLC AGRICOLA
# A media do preço de abertura no periodo foi R$ 24.06
# valor na data 2018-01-03  foi de  R$ 14.37
# valor na data 2021-03-30  foi de R$ 44.12
# A variação do preço no periodo foi 67.43% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# SLED3.SA
# O Nome da empresa é SARAIVA LIVR
# A media do preço de abertura no periodo foi R$ 2.70
# valor na data 2018-01-03  foi de  R$ 4.77
# valor na data 2021-03-30  foi de R$ 0.95
# A variação do preço no periodo foi -402.11% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# SLED4.SA
# O Nome da empresa é SARAIVA LIVR
# A media do preço de abertura no periodo foi R$ 2.04
# valor na data 2018-01-03  foi de  R$ 4.59
# valor na data 2021-03-30  foi de R$ 0.57
# A variação do preço no periodo foi -705.26% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# SMLS3.SA
# O Nome da empresa é SMILES
# A media do preço de abertura no periodo foi R$ 39.11
# valor na data 2018-01-03  foi de  R$ 78.84
# valor na data 2021-03-30  foi de R$ 25.64
# A variação do preço no periodo foi -207.49% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# SMTO3.SA
# O Nome da empresa é SAO MARTINHO
# A media do preço de abertura no periodo foi R$ 21.10
# valor na data 2018-01-03  foi de  R$ 19.37
# valor na data 2021-03-30  foi de R$ 31.04
# A variação do preço no periodo foi 37.60% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# SNSY3.SA
# O Nome da empresa é SANSUY
# A media do preço de abertura no periodo foi R$ 6.79
# valor na data 2018-01-03  foi de  R$ 1.12
# valor na data 2021-03-30  foi de R$ 14.17
# A variação do preço no periodo foi 92.10% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# SQIA3.SA
# O Nome da empresa é SINQIA
# A media do preço de abertura no periodo foi R$ 14.50
# valor na data 2018-01-03  foi de  R$ 6.75
# valor na data 2021-03-30  foi de R$ 22.79
# A variação do preço no periodo foi 70.38% foi de R$ 2021-03-30
# O setor da empresa é Tecnologia da Informação
#
#
# STBP3.SA
# O Nome da empresa é SANTOS BRP
# A media do preço de abertura no periodo foi R$ 4.80
# valor na data 2018-01-03  foi de  R$ 3.47
# valor na data 2021-03-30  foi de R$ 6.91
# A variação do preço no periodo foi 49.78% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# SULA3.SA
# O Nome da empresa é SUL AMERICA
# A media do preço de abertura no periodo foi R$ 14.21
# valor na data 2018-01-03  foi de  R$ 5.55
# valor na data 2021-03-30  foi de R$ 13.70
# A variação do preço no periodo foi 59.49% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# SULA4.SA
# O Nome da empresa é SUL AMERICA
# A media do preço de abertura no periodo foi R$ 9.99
# valor na data 2018-01-03  foi de  R$ 5.71
# valor na data 2021-03-30  foi de R$ 10.95
# A variação do preço no periodo foi 47.85% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# SULA11.SA
# O Nome da empresa é SUL AMERICA
# A media do preço de abertura no periodo foi R$ 34.33
# valor na data 2018-01-03  foi de  R$ 17.69
# valor na data 2021-03-30  foi de R$ 35.24
# A variação do preço no periodo foi 49.80% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# SUZB3.SA
# O Nome da empresa é SUZANO S.A.
# A media do preço de abertura no periodo foi R$ 42.68
# valor na data 2018-01-03  foi de  R$ 18.86
# valor na data 2021-03-30  foi de R$ 74.03
# A variação do preço no periodo foi 74.52% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# TAEE3.SA
# O Nome da empresa é TAESA
# A media do preço de abertura no periodo foi R$ 9.17
# valor na data 2018-01-03  foi de  R$ 7.50
# valor na data 2021-03-30  foi de R$ 13.15
# A variação do preço no periodo foi 42.97% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# TAEE4.SA
# O Nome da empresa é TAESA
# A media do preço de abertura no periodo foi R$ 8.76
# valor na data 2018-01-03  foi de  R$ 7.00
# valor na data 2021-03-30  foi de R$ 13.14
# A variação do preço no periodo foi 46.73% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# TAEE11.SA
# O Nome da empresa é TAESA
# A media do preço de abertura no periodo foi R$ 26.51
# valor na data 2018-01-03  foi de  R$ 21.53
# valor na data 2021-03-30  foi de R$ 39.35
# A variação do preço no periodo foi 45.29% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# TASA3.SA
# O Nome da empresa é TAURUS ARMAS
# A media do preço de abertura no periodo foi R$ 5.86
# valor na data 2018-01-03  foi de  R$ 1.90
# valor na data 2021-03-30  foi de R$ 23.62
# A variação do preço no periodo foi 91.96% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# TASA4.SA
# O Nome da empresa é TAURUS ARMAS
# A media do preço de abertura no periodo foi R$ 5.98
# valor na data 2018-01-03  foi de  R$ 2.04
# valor na data 2021-03-30  foi de R$ 22.73
# A variação do preço no periodo foi 91.03% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# TCNO3.SA
# O Nome da empresa é TECNOSOLO
# A media do preço de abertura no periodo foi R$ 1.83
# valor na data 2018-01-03  foi de  R$ 2.75
# valor na data 2021-03-30  foi de R$ 2.14
# A variação do preço no periodo foi -28.50% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# TCNO4.SA
# O Nome da empresa é TECNOSOLO
# A media do preço de abertura no periodo foi R$ 1.54
# valor na data 2018-01-03  foi de  R$ 2.78
# valor na data 2021-03-30  foi de R$ 1.46
# A variação do preço no periodo foi -90.41% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# TCSA3.SA
# O Nome da empresa é TECNISA
# A media do preço de abertura no periodo foi R$ 13.04
# valor na data 2018-01-03  foi de  R$ 22.10
# valor na data 2021-03-30  foi de R$ 7.63
# A variação do preço no periodo foi -189.65% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# TECN3.SA
# O Nome da empresa é TECHNOS
# A media do preço de abertura no periodo foi R$ 2.13
# valor na data 2018-01-03  foi de  R$ 3.90
# valor na data 2021-03-30  foi de R$ 1.56
# A variação do preço no periodo foi -150.00% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# TEKA3.SA
# O Nome da empresa é TEKA
# A media do preço de abertura no periodo foi R$ 16.12
# valor na data 2018-01-03  foi de  R$ 11.89
# valor na data 2021-03-30  foi de R$ 44.00
# A variação do preço no periodo foi 72.98% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# TEKA4.SA
# O Nome da empresa é TEKA
# A media do preço de abertura no periodo foi R$ 9.20
# valor na data 2018-01-03  foi de  R$ 6.75
# valor na data 2021-03-30  foi de R$ 18.24
# A variação do preço no periodo foi 62.99% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# TELB3.SA
# O Nome da empresa é TELEBRAS
# A media do preço de abertura no periodo foi R$ 69.78
# valor na data 2018-01-03  foi de  R$ 37.40
# valor na data 2021-03-30  foi de R$ 73.88
# A variação do preço no periodo foi 49.38% foi de R$ 2021-03-30
# O setor da empresa é Comunicações
#
#
# TELB4.SA
# O Nome da empresa é TELEBRAS
# A media do preço de abertura no periodo foi R$ 27.67
# valor na data 2018-01-03  foi de  R$ 22.89
# valor na data 2021-03-30  foi de R$ 26.79
# A variação do preço no periodo foi 14.56% foi de R$ 2021-03-30
# O setor da empresa é Comunicações
#
#
# TEND3.SA
# O Nome da empresa é TENDA
# A media do preço de abertura no periodo foi R$ 22.35
# valor na data 2018-01-03  foi de  R$ 9.97
# valor na data 2021-03-30  foi de R$ 26.61
# A variação do preço no periodo foi 62.53% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# TESA3.SA
# O Nome da empresa é TERRA SANTA
# A media do preço de abertura no periodo foi R$ 16.26
# valor na data 2018-01-03  foi de  R$ 14.80
# valor na data 2021-03-30  foi de R$ 40.01
# A variação do preço no periodo foi 63.01% foi de R$ 2021-03-30
# O setor da empresa é Consumo não Cíclico
#
#
# TGMA3.SA
# O Nome da empresa é TEGMA
# A media do preço de abertura no periodo foi R$ 25.81
# valor na data 2018-01-03  foi de  R$ 21.02
# valor na data 2021-03-30  foi de R$ 19.64
# A variação do preço no periodo foi -7.03% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# TIMS3.SA
# O Nome da empresa é TIM
# A media do preço de abertura no periodo foi R$ 13.38
# valor na data 2018-01-03  foi de  R$ 13.29
# valor na data 2021-03-30  foi de R$ 12.91
# A variação do preço no periodo foi -2.94% foi de R$ 2021-03-30
# O setor da empresa é Comunicações
#
#
# TKNO3.SA
# O Nome da empresa é TEKNO
# A media do preço de abertura no periodo foi R$ 83.21
# valor na data 2018-01-03  foi de  R$ 83.21
# valor na data 2021-03-30  foi de R$ 83.21
# A variação do preço no periodo foi 0.00% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# TKNO4.SA
# O Nome da empresa é TEKNO
# A media do preço de abertura no periodo foi R$ 36.24
# valor na data 2018-01-03  foi de  R$ 35.00
# valor na data 2021-03-30  foi de R$ 46.99
# A variação do preço no periodo foi 25.52% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# TOTS3.SA
# O Nome da empresa é TOTVS
# A media do preço de abertura no periodo foi R$ 17.81
# valor na data 2018-01-03  foi de  R$ 10.46
# valor na data 2021-03-30  foi de R$ 29.16
# A variação do preço no periodo foi 64.13% foi de R$ 2021-03-30
# O setor da empresa é Tecnologia da Informação
#
#
# TPIS3.SA
# O Nome da empresa é TRIUNFO PART
# A media do preço de abertura no periodo foi R$ 1.77
# valor na data 2018-01-03  foi de  R$ 3.60
# valor na data 2021-03-30  foi de R$ 2.13
# A variação do preço no periodo foi -69.01% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# TRIS3.SA
# O Nome da empresa é TRISUL
# A media do preço de abertura no periodo foi R$ 7.92
# valor na data 2018-01-03  foi de  R$ 2.19
# valor na data 2021-03-30  foi de R$ 10.02
# A variação do preço no periodo foi 78.14% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# TRPL3.SA
# O Nome da empresa é TRAN PAULIST
# A media do preço de abertura no periodo foi R$ 22.60
# valor na data 2018-01-03  foi de  R$ 14.50
# valor na data 2021-03-30  foi de R$ 31.20
# A variação do preço no periodo foi 53.53% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# TRPL4.SA
# O Nome da empresa é TRAN PAULIST
# A media do preço de abertura no periodo foi R$ 20.73
# valor na data 2018-01-03  foi de  R$ 16.64
# valor na data 2021-03-30  foi de R$ 26.34
# A variação do preço no periodo foi 36.83% foi de R$ 2021-03-30
# O setor da empresa é Utilidade Pública
#
#
# TUPY3.SA
# O Nome da empresa é TUPY
# A media do preço de abertura no periodo foi R$ 19.48
# valor na data 2018-01-03  foi de  R$ 19.68
# valor na data 2021-03-30  foi de R$ 20.50
# A variação do preço no periodo foi 4.00% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# UCAS3.SA
# O Nome da empresa é UNICASA
# A media do preço de abertura no periodo foi R$ 3.74
# valor na data 2018-01-03  foi de  R$ 2.49
# valor na data 2021-03-30  foi de R$ 4.36
# A variação do preço no periodo foi 42.89% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# UGPA3.SA
# O Nome da empresa é ULTRAPAR
# A media do preço de abertura no periodo foi R$ 23.07
# valor na data 2018-01-03  foi de  R$ 39.00
# valor na data 2021-03-30  foi de R$ 21.55
# A variação do preço no periodo foi -80.97% foi de R$ 2021-03-30
# O setor da empresa é Petróleo, Gás e Biocombustíveis
#
#
# UNIP3.SA
# O Nome da empresa é UNIPAR
# A media do preço de abertura no periodo foi R$ 33.21
# valor na data 2018-01-03  foi de  R$ 14.37
# valor na data 2021-03-30  foi de R$ 64.73
# A variação do preço no periodo foi 77.80% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# USIM3.SA
# O Nome da empresa é USIMINAS
# A media do preço de abertura no periodo foi R$ 11.22
# valor na data 2018-01-03  foi de  R$ 12.33
# valor na data 2021-03-30  foi de R$ 17.63
# A variação do preço no periodo foi 30.06% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# VALE3.SA
# O Nome da empresa é VALE
# A media do preço de abertura no periodo foi R$ 56.05
# valor na data 2018-01-03  foi de  R$ 42.37
# valor na data 2021-03-30  foi de R$ 98.50
# A variação do preço no periodo foi 56.98% foi de R$ 2021-03-30
# O setor da empresa é Materiais Básicos
#
#
# VIVR3.SA
# O Nome da empresa é VIVER
# A media do preço de abertura no periodo foi R$ 3.51
# valor na data 2018-01-03  foi de  R$ 14.10
# valor na data 2021-03-30  foi de R$ 1.24
# A variação do preço no periodo foi -1037.10% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# VIVT3.SA
# O Nome da empresa é TELEF BRASIL
# A media do preço de abertura no periodo foi R$ 44.99
# valor na data 2018-01-03  foi de  R$ 40.90
# valor na data 2021-03-30  foi de R$ 45.87
# A variação do preço no periodo foi 10.83% foi de R$ 2021-03-30
# O setor da empresa é Comunicações
#
#
# VLID3.SA
# O Nome da empresa é VALID
# A media do preço de abertura no periodo foi R$ 14.62
# valor na data 2018-01-03  foi de  R$ 19.58
# valor na data 2021-03-30  foi de R$ 9.11
# A variação do preço no periodo foi -114.93% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# VSPT3.SA
# O Nome da empresa é FER C ATLANT
# A media do preço de abertura no periodo foi R$ 1.50
# valor na data 2018-01-03  foi de  R$ 1.50
# valor na data 2021-03-30  foi de R$ 1.50
# A variação do preço no periodo foi 0.00% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# VULC3.SA
# O Nome da empresa é VULCABRAS
# A media do preço de abertura no periodo foi R$ 7.20
# valor na data 2018-01-03  foi de  R$ 10.18
# valor na data 2021-03-30  foi de R$ 7.24
# A variação do preço no periodo foi -40.61% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# VVAR3.SA
# O Nome da empresa é VIAVAREJO
# A media do preço de abertura no periodo foi R$ 9.81
# valor na data 2018-01-03  foi de  R$ 7.91
# valor na data 2021-03-30  foi de R$ 12.45
# A variação do preço no periodo foi 36.47% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# WEGE3.SA
# O Nome da empresa é WEG
# A media do preço de abertura no periodo foi R$ 36.09
# valor na data 2018-01-03  foi de  R$ 19.17
# valor na data 2021-03-30  foi de R$ 75.45
# A variação do preço no periodo foi 74.59% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# WHRL3.SA
# O Nome da empresa é WHIRLPOOL
# A media do preço de abertura no periodo foi R$ 5.95
# valor na data 2018-01-03  foi de  R$ 4.57
# valor na data 2021-03-30  foi de R$ 6.98
# A variação do preço no periodo foi 34.53% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# WHRL4.SA
# O Nome da empresa é WHIRLPOOL
# A media do preço de abertura no periodo foi R$ 6.31
# valor na data 2018-01-03  foi de  R$ 4.95
# valor na data 2021-03-30  foi de R$ 7.83
# A variação do preço no periodo foi 36.78% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico
#
#
# WIZS3.SA
# O Nome da empresa é WIZ S.A.
# A media do preço de abertura no periodo foi R$ 10.08
# valor na data 2018-01-03  foi de  R$ 12.24
# valor na data 2021-03-30  foi de R$ 7.19
# A variação do preço no periodo foi -70.24% foi de R$ 2021-03-30
# O setor da empresa é Financeiro
#
#
# WLMM3.SA
# O Nome da empresa é WLM IND COM
# A media do preço de abertura no periodo foi R$ 10.51
# valor na data 2018-01-03  foi de  R$ 7.40
# valor na data 2021-03-30  foi de R$ 19.30
# A variação do preço no periodo foi 61.66% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# WLMM4.SA
# O Nome da empresa é WLM IND COM
# A media do preço de abertura no periodo foi R$ 12.09
# valor na data 2018-01-03  foi de  R$ 5.10
# valor na data 2021-03-30  foi de R$ 29.45
# A variação do preço no periodo foi 82.68% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# WSON33.SA
# O Nome da empresa é WILSON SONS
# A media do preço de abertura no periodo foi R$ 40.48
# valor na data 2018-01-03  foi de  R$ 38.61
# valor na data 2021-03-30  foi de R$ 42.98
# A variação do preço no periodo foi 10.17% foi de R$ 2021-03-30
# O setor da empresa é Bens Industriais
#
#
# YDUQ3.SA
# O Nome da empresa é YDUQS PART
# A media do preço de abertura no periodo foi R$ 31.98
# valor na data 2018-01-03  foi de  R$ 34.33
# valor na data 2021-03-30  foi de R$ 28.30
# A variação do preço no periodo foi -21.31% foi de R$ 2021-03-30
# O setor da empresa é Consumo Cíclico

# %% [markdown]
#  Após organizado em uma lista de dicionários, organizamos esses dicionarios de maneira a observar quais os tickers que tiveram maiores valorizações no período e os que possuem maiores médias.
#
#  Foram escolhidos 50 melhores tickers para analise com base no ganho e os 50 melhores tickers com base na média de valores.

# %%
# reordenação da lista2 de maneira mostrando quais tickers tiveram os
# valores medios mais altos e quai tickers tiveram os maiores ganhos 

lista_ordenada_media = sorted(lista2, key=lambda x: x['media'], reverse=True)
lista_ordenada_ganho = sorted(lista2, key=lambda x: x['variacao'], reverse=True)

quant_tickers = 50 # Quantidade de tickers se serão analizados 

# Ordenação pela media do valor do ticker
i=0
print('Ordenação pela media do valor do ticker \n')
for i in range(quant_tickers):
  #impressão dos tickers de que tiveram os maiores ganhos
  print(' {}° ticker foi  {} \n '.format(i+1, lista_ordenada_media[i]))
  i=+1


# Ordenaçao pelo ganho do ticker 
i=0
print('Ordenação pela ganho do ticker \n')
for i in range(quant_tickers):
  #impressão dos tickers de que tiveram os maiores ganhos
  print(' {}° ticker foi  {} \n '.format(i+1, lista_ordenada_ganho[i]))
  i=+1
# Out:
# Ordenação pela media do valor do ticker
#
#  1° ticker foi  {'ticker': 'EEEL4.SA', 'Nome': 'CEEE-GT', 'media': 329.2289698492447, 'valor_aber_ini': 160.0, 'valor_aber_final': 600.0, 'variacao': 73.33333333333333, 'Setor': 'Utilidade Pública'}
#
#  2° ticker foi  {'ticker': 'EEEL3.SA', 'Nome': 'CEEE-GT', 'media': 297.91966080402017, 'valor_aber_ini': 165.0, 'valor_aber_final': 547.5, 'variacao': 69.86301369863014, 'Setor': 'Utilidade Pública'}
#
#  3° ticker foi  {'ticker': 'BMKS3.SA', 'Nome': 'BIC MONARK', 'media': 265.47336683417063, 'valor_aber_ini': 350.0, 'valor_aber_final': 242.24, 'variacao': -44.48480845442536, 'Setor': 'Consumo Cíclico'}
#
#  4° ticker foi  {'ticker': 'PPAR3.SA', 'Nome': 'POLPAR', 'media': 250.01999999999714, 'valor_aber_ini': 250.02, 'valor_aber_final': 250.02, 'variacao': 0.0, 'Setor': 'Outros'}
#
#  5° ticker foi  {'ticker': 'MOAR3.SA', 'Nome': 'MONT ARANHA', 'media': 177.21604271356784, 'valor_aber_ini': 148.0, 'valor_aber_final': 249.99, 'variacao': 40.79763190527621, 'Setor': 'Financeiro'}
#
#  6° ticker foi  {'ticker': 'MMAQ4.SA', 'Nome': 'MINASMAQUINA', 'media': 163.86000000000024, 'valor_aber_ini': 163.86, 'valor_aber_final': 163.86, 'variacao': 0.0, 'Setor': 'Bens Industriais'}
#
#  7° ticker foi  {'ticker': 'MTIG3.SA', 'Nome': 'METAL IGUACU', 'media': 156.30000000000203, 'valor_aber_ini': 156.3, 'valor_aber_final': 156.3, 'variacao': 0.0, 'Setor': 'Materiais Básicos'}
#
#  8° ticker foi  {'ticker': 'CGAS3.SA', 'Nome': 'COMGAS', 'media': 109.36663316582916, 'valor_aber_ini': 59.48, 'valor_aber_final': 150.0, 'variacao': 60.34666666666668, 'Setor': 'Utilidade Pública'}
#
#  9° ticker foi  {'ticker': 'CALI3.SA', 'Nome': 'CONST A LIND', 'media': 105.21433128834182, 'valor_aber_ini': 126.01, 'valor_aber_final': 98.18, 'variacao': -28.3458952943573, 'Setor': 'Consumo Cíclico'}
#
#  10° ticker foi  {'ticker': 'RSUL4.SA', 'Nome': 'RIOSULENSE', 'media': 104.24854271356782, 'valor_aber_ini': 34.0, 'valor_aber_final': 205.0, 'variacao': 83.41463414634147, 'Setor': 'Bens Industriais'}
#
#  11° ticker foi  {'ticker': 'GSHP3.SA', 'Nome': 'GENERALSHOPP', 'media': 93.31016331658286, 'valor_aber_ini': 194.4, 'valor_aber_final': 46.93, 'variacao': -314.2339654805029, 'Setor': 'Financeiro'}
#
#  12° ticker foi  {'ticker': 'BAHI3.SA', 'Nome': 'BAHEMA', 'media': 90.86548994974866, 'valor_aber_ini': 53.16, 'valor_aber_final': 70.5, 'variacao': 24.59574468085107, 'Setor': 'Consumo Cíclico'}
#
#  13° ticker foi  {'ticker': 'ECPR4.SA', 'Nome': 'ENCORPAR', 'media': 83.85487437185964, 'valor_aber_ini': 39.87, 'valor_aber_final': 74.96, 'variacao': 46.81163287086446, 'Setor': 'Consumo Cíclico'}
#
#  14° ticker foi  {'ticker': 'TKNO3.SA', 'Nome': 'TEKNO', 'media': 83.2099999999995, 'valor_aber_ini': 83.21, 'valor_aber_final': 83.21, 'variacao': 0.0, 'Setor': 'Materiais Básicos'}
#
#  15° ticker foi  {'ticker': 'PCAR3.SA', 'Nome': 'P.ACUCAR-CBD', 'media': 82.09298994974858, 'valor_aber_ini': 84.99, 'valor_aber_final': 35.5, 'variacao': -139.40845070422532, 'Setor': 'Consumo não Cíclico'}
#
#  16° ticker foi  {'ticker': 'CORR4.SA', 'Nome': 'COR RIBEIRO', 'media': 81.89809045226153, 'valor_aber_ini': 145.0, 'valor_aber_final': 82.0, 'variacao': -76.82926829268293, 'Setor': 'Financeiro'}
#
#  17° ticker foi  {'ticker': 'MGEL3.SA', 'Nome': 'MANGELS INDL', 'media': 75.0, 'valor_aber_ini': 75.0, 'valor_aber_final': 75.0, 'variacao': 0.0, 'Setor': 'Materiais Básicos'}
#
#  18° ticker foi  {'ticker': 'ECPR3.SA', 'Nome': 'ENCORPAR', 'media': 73.54905778894435, 'valor_aber_ini': 33.0, 'valor_aber_final': 77.0, 'variacao': 57.142857142857146, 'Setor': 'Consumo Cíclico'}
#
#  19° ticker foi  {'ticker': 'CEED4.SA', 'Nome': 'CEEE-D', 'media': 71.88324120603023, 'valor_aber_ini': 33.0, 'valor_aber_final': 70.0, 'variacao': 52.857142857142854, 'Setor': 'Utilidade Pública'}
#
#  20° ticker foi  {'ticker': 'TELB3.SA', 'Nome': 'TELEBRAS', 'media': 69.77942211055276, 'valor_aber_ini': 37.4, 'valor_aber_final': 73.88, 'variacao': 49.37736870600974, 'Setor': 'Comunicações'}
#
#  21° ticker foi  {'ticker': 'CALI4.SA', 'Nome': 'CONST A LIND', 'media': 67.96968592964815, 'valor_aber_ini': 100.0, 'valor_aber_final': 50.0, 'variacao': -100.0, 'Setor': 'Consumo Cíclico'}
#
#  22° ticker foi  {'ticker': 'LIPR3.SA', 'Nome': 'ELETROPAR', 'media': 65.63109296482405, 'valor_aber_ini': 52.95, 'valor_aber_final': 69.9, 'variacao': 24.24892703862661, 'Setor': 'Utilidade Pública'}
#
#  23° ticker foi  {'ticker': 'CEED3.SA', 'Nome': 'CEEE-D', 'media': 64.6813693467337, 'valor_aber_ini': 29.99, 'valor_aber_final': 60.0, 'variacao': 50.016666666666666, 'Setor': 'Utilidade Pública'}
#
#  24° ticker foi  {'ticker': 'FRIO3.SA', 'Nome': 'METALFRIO', 'media': 61.849786432160876, 'valor_aber_ini': 42.0, 'valor_aber_final': 63.0, 'variacao': 33.333333333333336, 'Setor': 'Bens Industriais'}
#
#  25° ticker foi  {'ticker': 'BNBR3.SA', 'Nome': 'NORD BRASIL', 'media': 60.744321608040245, 'valor_aber_ini': 37.0, 'valor_aber_final': 70.5, 'variacao': 47.5177304964539, 'Setor': 'Financeiro'}
#
#  26° ticker foi  {'ticker': 'MTIG4.SA', 'Nome': 'METAL IGUACU', 'media': 58.274798994974944, 'valor_aber_ini': 20.7, 'valor_aber_final': 51.0, 'variacao': 59.411764705882355, 'Setor': 'Materiais Básicos'}
#
#  27° ticker foi  {'ticker': 'CSAN3.SA', 'Nome': 'COSAN', 'media': 56.53654522613063, 'valor_aber_ini': 43.3, 'valor_aber_final': 94.0, 'variacao': 53.93617021276596, 'Setor': 'Petróleo, Gás e Biocombustíveis'}
#
#  28° ticker foi  {'ticker': 'VALE3.SA', 'Nome': 'VALE', 'media': 56.05226130653257, 'valor_aber_ini': 42.37, 'valor_aber_final': 98.5, 'variacao': 56.984771573604064, 'Setor': 'Materiais Básicos'}
#
#  29° ticker foi  {'ticker': 'AHEB3.SA', 'Nome': 'SPTURIS', 'media': 55.64693467336669, 'valor_aber_ini': 100.61, 'valor_aber_final': 21.9, 'variacao': -359.406392694064, 'Setor': 'Consumo Cíclico'}
#
#  30° ticker foi  {'ticker': 'BTOW3.SA', 'Nome': 'B2W DIGITAL', 'media': 55.544070351758855, 'valor_aber_ini': 20.31, 'valor_aber_final': 62.12, 'variacao': 67.30521571152609, 'Setor': 'Consumo Cíclico'}
#
#  31° ticker foi  {'ticker': 'ARZZ3.SA', 'Nome': 'AREZZO CO', 'media': 54.0113065326633, 'valor_aber_ini': 60.91, 'valor_aber_final': 70.84, 'variacao': 14.017504234895549, 'Setor': 'Consumo Cíclico'}
#
#  32° ticker foi  {'ticker': 'CEBR3.SA', 'Nome': 'CEB', 'media': 53.47168341708548, 'valor_aber_ini': 26.0, 'valor_aber_final': 185.0, 'variacao': 85.94594594594595, 'Setor': 'Utilidade Pública'}
#
#  33° ticker foi  {'ticker': 'PSSA3.SA', 'Nome': 'PORTO SEGURO', 'media': 52.63271356783921, 'valor_aber_ini': 37.55, 'valor_aber_final': 47.48, 'variacao': 20.91406908171862, 'Setor': 'Financeiro'}
#
#  34° ticker foi  {'ticker': 'COCE3.SA', 'Nome': 'COELCE', 'media': 51.88675879396978, 'valor_aber_ini': 48.65, 'valor_aber_final': 51.24, 'variacao': 5.054644808743176, 'Setor': 'Utilidade Pública'}
#
#  35° ticker foi  {'ticker': 'GNDI3.SA', 'Nome': 'INTERMEDICA', 'media': 51.42581137309294, 'valor_aber_ini': 20.9, 'valor_aber_final': 84.38, 'variacao': 75.2310974164494, 'Setor': 'Saúde'}
#
#  36° ticker foi  {'ticker': 'BPAC11.SA', 'Nome': 'BTGP BANCO', 'media': 51.32757537688447, 'valor_aber_ini': 19.4, 'valor_aber_final': 98.02, 'variacao': 80.20812079167517, 'Setor': 'Financeiro'}
#
#  37° ticker foi  {'ticker': 'BAUH4.SA', 'Nome': 'EXCELSIOR', 'media': 51.017902010050335, 'valor_aber_ini': 12.36, 'valor_aber_final': 95.0, 'variacao': 86.98947368421052, 'Setor': 'Consumo não Cíclico'}
#
#  38° ticker foi  {'ticker': 'DASA3.SA', 'Nome': 'DASA', 'media': 50.254874371859245, 'valor_aber_ini': 28.0, 'valor_aber_final': 149.49, 'variacao': 81.26965014382232, 'Setor': 'Saúde'}
#
#  39° ticker foi  {'ticker': 'PEAB4.SA', 'Nome': 'PAR AL BAHIA', 'media': 49.727349246231114, 'valor_aber_ini': 39.01, 'valor_aber_final': 68.0, 'variacao': 42.63235294117647, 'Setor': 'Financeiro'}
#
#  40° ticker foi  {'ticker': 'CSAB4.SA', 'Nome': 'SEG AL BAHIA', 'media': 48.9017587939698, 'valor_aber_ini': 56.02, 'valor_aber_final': 50.99, 'variacao': -9.864679348891942, 'Setor': 'Financeiro'}
#
#  41° ticker foi  {'ticker': 'CSAB3.SA', 'Nome': 'SEG AL BAHIA', 'media': 48.61433417085431, 'valor_aber_ini': 57.0, 'valor_aber_final': 49.08, 'variacao': -16.13691931540343, 'Setor': 'Financeiro'}
#
#  42° ticker foi  {'ticker': 'MSPA3.SA', 'Nome': 'MELHOR SP', 'media': 48.227726130653274, 'valor_aber_ini': 47.0, 'valor_aber_final': 48.0, 'variacao': 2.0833333333333335, 'Setor': 'Materiais Básicos'}
#
#  43° ticker foi  {'ticker': 'CLSC3.SA', 'Nome': 'CELESC', 'media': 48.17114321608069, 'valor_aber_ini': 30.0, 'valor_aber_final': 58.9, 'variacao': 49.06621392190153, 'Setor': 'Utilidade Pública'}
#
#  44° ticker foi  {'ticker': 'PEAB3.SA', 'Nome': 'PAR AL BAHIA', 'media': 47.550527638191, 'valor_aber_ini': 40.0, 'valor_aber_final': 60.96, 'variacao': 34.38320209973753, 'Setor': 'Financeiro'}
#
#  45° ticker foi  {'ticker': 'MSPA4.SA', 'Nome': 'MELHOR SP', 'media': 47.18620603015036, 'valor_aber_ini': 42.0, 'valor_aber_final': 42.1, 'variacao': 0.2375296912114048, 'Setor': 'Materiais Básicos'}
#
#  46° ticker foi  {'ticker': 'CEGR3.SA', 'Nome': 'CEG', 'media': 46.25224874371845, 'valor_aber_ini': 27.0, 'valor_aber_final': 61.26, 'variacao': 55.92556317335945, 'Setor': 'Utilidade Pública'}
#
#  47° ticker foi  {'ticker': 'VIVT3.SA', 'Nome': 'TELEF BRASIL', 'media': 44.989459798994986, 'valor_aber_ini': 40.9, 'valor_aber_final': 45.87, 'variacao': 10.83496838892522, 'Setor': 'Comunicações'}
#
#  48° ticker foi  {'ticker': 'CLSC4.SA', 'Nome': 'CELESC', 'media': 44.88006281407034, 'valor_aber_ini': 26.9, 'valor_aber_final': 58.3, 'variacao': 53.85934819897084, 'Setor': 'Utilidade Pública'}
#
#  49° ticker foi  {'ticker': 'SBSP3.SA', 'Nome': 'SABESP', 'media': 43.256834170854304, 'valor_aber_ini': 34.33, 'valor_aber_final': 41.47, 'variacao': 17.217265493127563, 'Setor': 'Utilidade Pública'}
#
#  50° ticker foi  {'ticker': 'FIGE3.SA', 'Nome': 'INVEST BEMGE', 'media': 43.0, 'valor_aber_ini': 43.0, 'valor_aber_final': 43.0, 'variacao': 0.0, 'Setor': 'Outros'}
#
# Ordenação pela ganho do ticker
#
#  1° ticker foi  {'ticker': 'ODER4.SA', 'Nome': 'ODERICH', 'media': 20.574020100502718, 'valor_aber_ini': 11.27, 'valor_aber_final': 190.0, 'variacao': 94.06842105263158, 'Setor': 'Consumo não Cíclico'}
#
#  2° ticker foi  {'ticker': 'MAPT4.SA', 'Nome': 'CEMEPE', 'media': 31.302675879396975, 'valor_aber_ini': 3.5, 'valor_aber_final': 50.0, 'variacao': 93.0, 'Setor': 'Outros'}
#
#  3° ticker foi  {'ticker': 'BSLI3.SA', 'Nome': 'BRB BANCO', 'media': 11.569472361809035, 'valor_aber_ini': 3.5, 'valor_aber_final': 49.12, 'variacao': 92.87459283387622, 'Setor': 'Financeiro'}
#
#  4° ticker foi  {'ticker': 'SNSY3.SA', 'Nome': 'SANSUY', 'media': 6.792701005025125, 'valor_aber_ini': 1.12, 'valor_aber_final': 14.17, 'variacao': 92.09597741707833, 'Setor': 'Materiais Básicos'}
#
#  5° ticker foi  {'ticker': 'IGBR3.SA', 'Nome': 'IGB S/A', 'media': 3.328391959798998, 'valor_aber_ini': 1.14, 'valor_aber_final': 14.2, 'variacao': 91.97183098591549, 'Setor': 'Financeiro'}
#
#  6° ticker foi  {'ticker': 'TASA3.SA', 'Nome': 'TAURUS ARMAS', 'media': 5.859874371859294, 'valor_aber_ini': 1.9, 'valor_aber_final': 23.62, 'variacao': 91.95596951735818, 'Setor': 'Bens Industriais'}
#
#  7° ticker foi  {'ticker': 'INEP4.SA', 'Nome': 'INEPAR', 'media': 8.713216080402008, 'valor_aber_ini': 2.9, 'valor_aber_final': 32.9, 'variacao': 91.18541033434651, 'Setor': 'Bens Industriais'}
#
#  8° ticker foi  {'ticker': 'BSLI4.SA', 'Nome': 'BRB BANCO', 'media': 8.709962311557792, 'valor_aber_ini': 3.11, 'valor_aber_final': 34.98, 'variacao': 91.10920526014866, 'Setor': 'Financeiro'}
#
#  9° ticker foi  {'ticker': 'TASA4.SA', 'Nome': 'TAURUS ARMAS', 'media': 5.977160804020096, 'valor_aber_ini': 2.04, 'valor_aber_final': 22.73, 'variacao': 91.02507699076111, 'Setor': 'Bens Industriais'}
#
#  10° ticker foi  {'ticker': 'PRIO3.SA', 'Nome': 'PETRORIO', 'media': 26.25207286432162, 'valor_aber_ini': 9.06, 'valor_aber_final': 94.58, 'variacao': 90.42080778177204, 'Setor': 'Petróleo, Gás e Biocombustíveis'}
#
#  11° ticker foi  {'ticker': 'MMXM3.SA', 'Nome': 'MMX MINER', 'media': 4.475, 'valor_aber_ini': 3.38, 'valor_aber_final': 33.41, 'variacao': 89.88326848249027, 'Setor': 'Materiais Básicos'}
#
#  12° ticker foi  {'ticker': 'MGLU3.SA', 'Nome': 'MAGAZ LUIZA', 'media': 11.13795226130653, 'valor_aber_ini': 2.52, 'valor_aber_final': 20.32, 'variacao': 87.59842519685039, 'Setor': 'Consumo Cíclico'}
#
#  13° ticker foi  {'ticker': 'MAPT3.SA', 'Nome': 'CEMEPE', 'media': 33.313907035175596, 'valor_aber_ini': 6.3, 'valor_aber_final': 50.01, 'variacao': 87.40251949610078, 'Setor': 'Outros'}
#
#  14° ticker foi  {'ticker': 'BAUH4.SA', 'Nome': 'EXCELSIOR', 'media': 51.017902010050335, 'valor_aber_ini': 12.36, 'valor_aber_final': 95.0, 'variacao': 86.98947368421052, 'Setor': 'Consumo não Cíclico'}
#
#  15° ticker foi  {'ticker': 'CEBR3.SA', 'Nome': 'CEB', 'media': 53.47168341708548, 'valor_aber_ini': 26.0, 'valor_aber_final': 185.0, 'variacao': 85.94594594594595, 'Setor': 'Utilidade Pública'}
#
#  16° ticker foi  {'ticker': 'EALT3.SA', 'Nome': 'ACO ALTONA', 'media': 9.024359296482396, 'valor_aber_ini': 2.3, 'valor_aber_final': 16.19, 'variacao': 85.79369981470043, 'Setor': 'Bens Industriais'}
#
#  17° ticker foi  {'ticker': 'GPCP3.SA', 'Nome': 'GPC PART', 'media': 7.185590452261305, 'valor_aber_ini': 3.2, 'valor_aber_final': 22.2, 'variacao': 85.58558558558559, 'Setor': 'Materiais Básicos'}
#
#  18° ticker foi  {'ticker': 'PPLA11.SA', 'Nome': 'PPLA', 'media': 5.377286432160804, 'valor_aber_ini': 1.53, 'valor_aber_final': 10.3, 'variacao': 85.14563106796118, 'Setor': 'Financeiro'}
#
#  19° ticker foi  {'ticker': 'EMAE4.SA', 'Nome': 'EMAE', 'media': 26.450452261306534, 'valor_aber_ini': 9.09, 'valor_aber_final': 60.5, 'variacao': 84.97520661157024, 'Setor': 'Utilidade Pública'}
#
#  20° ticker foi  {'ticker': 'RSUL4.SA', 'Nome': 'RIOSULENSE', 'media': 104.24854271356782, 'valor_aber_ini': 34.0, 'valor_aber_final': 205.0, 'variacao': 83.41463414634147, 'Setor': 'Bens Industriais'}
#
#  21° ticker foi  {'ticker': 'WLMM4.SA', 'Nome': 'WLM IND COM', 'media': 12.09095477386932, 'valor_aber_ini': 5.1, 'valor_aber_final': 29.45, 'variacao': 82.68251273344652, 'Setor': 'Bens Industriais'}
#
#  22° ticker foi  {'ticker': 'CTKA3.SA', 'Nome': 'KARSTEN', 'media': 10.442788944723619, 'valor_aber_ini': 4.45, 'valor_aber_final': 25.33, 'variacao': 82.43189893407028, 'Setor': 'Consumo Cíclico'}
#
#  23° ticker foi  {'ticker': 'BPAN4.SA', 'Nome': 'BANCO PAN', 'media': 12.470364321608036, 'valor_aber_ini': 1.94, 'valor_aber_final': 10.94, 'variacao': 82.26691042047533, 'Setor': 'Financeiro'}
#
#  24° ticker foi  {'ticker': 'LUXM4.SA', 'Nome': 'TREVISA', 'media': 26.70438442211058, 'valor_aber_ini': 12.0, 'valor_aber_final': 67.5, 'variacao': 82.22222222222223, 'Setor': 'Bens Industriais'}
#
#  25° ticker foi  {'ticker': 'DASA3.SA', 'Nome': 'DASA', 'media': 50.254874371859245, 'valor_aber_ini': 28.0, 'valor_aber_final': 149.49, 'variacao': 81.26965014382232, 'Setor': 'Saúde'}
#
#  26° ticker foi  {'ticker': 'BPAC3.SA', 'Nome': 'BTGP BANCO', 'media': 24.29374371859296, 'valor_aber_ini': 8.85, 'valor_aber_final': 46.3, 'variacao': 80.88552915766738, 'Setor': 'Financeiro'}
#
#  27° ticker foi  {'ticker': 'CEPE3.SA', 'Nome': 'CELPE', 'media': 31.971331658291685, 'valor_aber_ini': 24.53, 'valor_aber_final': 128.0, 'variacao': 80.8359375, 'Setor': 'Utilidade Pública'}
#
#  28° ticker foi  {'ticker': 'CTKA4.SA', 'Nome': 'KARSTEN', 'media': 8.987085427135668, 'valor_aber_ini': 3.78, 'valor_aber_final': 19.26, 'variacao': 80.37383177570094, 'Setor': 'Consumo Cíclico'}
#
#  29° ticker foi  {'ticker': 'MERC3.SA', 'Nome': 'MERC FINANC', 'media': 11.177148241206032, 'valor_aber_ini': 5.5, 'valor_aber_final': 28.02, 'variacao': 80.37116345467523, 'Setor': 'Financeiro'}
#
#  30° ticker foi  {'ticker': 'BPAC11.SA', 'Nome': 'BTGP BANCO', 'media': 51.32757537688447, 'valor_aber_ini': 19.4, 'valor_aber_final': 98.02, 'variacao': 80.20812079167517, 'Setor': 'Financeiro'}
#
#  31° ticker foi  {'ticker': 'ENMT4.SA', 'Nome': 'ENERGISA MT', 'media': 24.428241206030183, 'valor_aber_ini': 8.51, 'valor_aber_final': 41.99, 'variacao': 79.73326982614908, 'Setor': 'Utilidade Pública'}
#
#  32° ticker foi  {'ticker': 'LOGN3.SA', 'Nome': 'LOG-IN', 'media': 12.038228643216067, 'valor_aber_ini': 3.17, 'valor_aber_final': 15.55, 'variacao': 79.61414790996784, 'Setor': 'Bens Industriais'}
#
#  33° ticker foi  {'ticker': 'ENEV3.SA', 'Nome': 'ENEVA', 'media': 7.8929899497487455, 'valor_aber_ini': 3.56, 'valor_aber_final': 16.68, 'variacao': 78.65707434052759, 'Setor': 'Utilidade Pública'}
#
#  34° ticker foi  {'ticker': 'DOHL3.SA', 'Nome': 'DOHLER', 'media': 10.159912060301489, 'valor_aber_ini': 6.0, 'valor_aber_final': 27.67, 'variacao': 78.31586555836645, 'Setor': 'Consumo Cíclico'}
#
#  35° ticker foi  {'ticker': 'TRIS3.SA', 'Nome': 'TRISUL', 'media': 7.921130653266334, 'valor_aber_ini': 2.19, 'valor_aber_final': 10.02, 'variacao': 78.1437125748503, 'Setor': 'Consumo Cíclico'}
#
#  36° ticker foi  {'ticker': 'GPAR3.SA', 'Nome': 'CELGPAR', 'media': 23.582575376884407, 'valor_aber_ini': 13.99, 'valor_aber_final': 64.0, 'variacao': 78.140625, 'Setor': 'Utilidade Pública'}
#
#  37° ticker foi  {'ticker': 'UNIP3.SA', 'Nome': 'UNIPAR', 'media': 33.21417085427139, 'valor_aber_ini': 14.37, 'valor_aber_final': 64.73, 'variacao': 77.80009269272362, 'Setor': 'Materiais Básicos'}
#
#  38° ticker foi  {'ticker': 'APER3.SA', 'Nome': 'ALPER S.A.', 'media': 23.159296482412056, 'valor_aber_ini': 11.56, 'valor_aber_final': 51.16, 'variacao': 77.40422204847536, 'Setor': 'Financeiro'}
#
#  39° ticker foi  {'ticker': 'GNDI3.SA', 'Nome': 'INTERMEDICA', 'media': 51.42581137309294, 'valor_aber_ini': 20.9, 'valor_aber_final': 84.38, 'variacao': 75.2310974164494, 'Setor': 'Saúde'}
#
#  40° ticker foi  {'ticker': 'MNPR3.SA', 'Nome': 'MINUPAR', 'media': 4.492298994974872, 'valor_aber_ini': 2.71, 'valor_aber_final': 10.89, 'variacao': 75.1147842056933, 'Setor': 'Consumo não Cíclico'}
#
#  41° ticker foi  {'ticker': 'LUPA3.SA', 'Nome': 'LUPATECH', 'media': 1.9787562814070376, 'valor_aber_ini': 2.71, 'valor_aber_final': 10.79, 'variacao': 74.88415199258571, 'Setor': 'Petróleo, Gás e Biocombustíveis'}
#
#  42° ticker foi  {'ticker': 'WEGE3.SA', 'Nome': 'WEG', 'media': 36.085590452261336, 'valor_aber_ini': 19.17, 'valor_aber_final': 75.45, 'variacao': 74.5924453280318, 'Setor': 'Bens Industriais'}
#
#  43° ticker foi  {'ticker': 'SUZB3.SA', 'Nome': 'SUZANO S.A.', 'media': 42.67956030150759, 'valor_aber_ini': 18.86, 'valor_aber_final': 74.03, 'variacao': 74.52384168580305, 'Setor': 'Materiais Básicos'}
#
#  44° ticker foi  {'ticker': 'CSNA3.SA', 'Nome': 'SID NACIONAL', 'media': 14.446809045226136, 'valor_aber_ini': 9.49, 'valor_aber_final': 36.99, 'variacao': 74.34441741011084, 'Setor': 'Materiais Básicos'}
#
#  45° ticker foi  {'ticker': 'PATI3.SA', 'Nome': 'PANATLANTICA', 'media': 20.401783919597992, 'valor_aber_ini': 11.5, 'valor_aber_final': 44.0, 'variacao': 73.86363636363636, 'Setor': 'Materiais Básicos'}
#
#  46° ticker foi  {'ticker': 'EEEL4.SA', 'Nome': 'CEEE-GT', 'media': 329.2289698492447, 'valor_aber_ini': 160.0, 'valor_aber_final': 600.0, 'variacao': 73.33333333333333, 'Setor': 'Utilidade Pública'}
#
#  47° ticker foi  {'ticker': 'JHSF3.SA', 'Nome': 'JHSF PART', 'media': 4.294660804020097, 'valor_aber_ini': 1.93, 'valor_aber_final': 7.17, 'variacao': 73.08228730822873, 'Setor': 'Consumo Cíclico'}
#
#  48° ticker foi  {'ticker': 'TEKA3.SA', 'Nome': 'TEKA', 'media': 16.118391959798977, 'valor_aber_ini': 11.89, 'valor_aber_final': 44.0, 'variacao': 72.97727272727273, 'Setor': 'Consumo Cíclico'}
#
#  49° ticker foi  {'ticker': 'ROMI3.SA', 'Nome': 'INDS ROMI', 'media': 10.6731783919598, 'valor_aber_ini': 7.51, 'valor_aber_final': 27.1, 'variacao': 72.2878228782288, 'Setor': 'Bens Industriais'}
#
#  50° ticker foi  {'ticker': 'BMEB4.SA', 'Nome': 'MERC BRASIL', 'media': 10.55819095477385, 'valor_aber_ini': 5.09, 'valor_aber_final': 17.85, 'variacao': 71.48459383753502, 'Setor': 'Financeiro'}

# %% [markdown]
#  Agora que já temos os tickers que mais aumentaram o seu valor durante o perído, vamos verificar quais setores esses tickers pertencem e verificar se algum setor está em crescimento acelerado. Para verificar esse comportamento será utilizar um gráfico em barras.

# %%
# importação do pyplot
import matplotlib.pyplot as plt

# Veriicando a quantidade de vezes que cada setor apareceu  nos
# nos tickers mais valorizados 
lista_ganho = []
i=0
for i in range(quant_tickers):
  a = (dados[dados['Ticker']==lista_ordenada_ganho[i]['ticker']])
  lista_ganho.append(a.iloc[1, 11])
  i=+1

# separar os nomes dos setores em uma lista 
# e a quantidade de cada setor na outra lista

contagem = {}
for item in lista_ganho:
    if item in contagem:
        contagem[item] += 1
    else:
        contagem[item] = 1
quant = list(contagem.values())
setores = list(contagem.keys())


# Verificando a quantidade de empresas

lista_nomes_ganho = []
i=0
for i in range(quant_tickers):
  b = (dados[dados['Nome']==lista_ordenada_ganho[i]['Nome']])
  lista_nomes_ganho.append(b.iloc[1, 10])
  i=+1

# separar os nomes das empresas em uma lista 
# e a quantidade que cada empresa aparece na lista

contagem_ganho = {}
for item in lista_nomes_ganho:
    if item in contagem:
        contagem_ganho[item] += 1
    else:
        contagem_ganho[item] = 1
quant_nome = list(contagem_ganho.values())
setores_nome = list(contagem_ganho.keys())

# plotando em um gráfico de barras horizontal 
#criando o gráfico
plt.barh(setores, quant)

# criando título do gráfico e legenda
plt.title("Setores das empresas com maiores ganhos")
plt.xlabel("Quantidade de ocorrencias ")
plt.ylabel("setor");

# %% [markdown]
#  Analizando o gráfico acima é possível perceber que a maior parte das empresas que tiveram valorização nesse período  foram as empresas do setor de bens industriais, seguido por empresas do setor financeiro e empresas de utilidades públicas e consumo cíclico

# %% [markdown]
#  Vamos avaliar também quais foram os setores em que os tickers tiveram o valores médios mais altos. Para ajudar na visualização vamos utilizar também um gráfico de barras horizontais.

# %%
# importação do pyplot
import matplotlib.pyplot as plt

# Veriicando a quantidade de vezes que cada setor apareceu  nos
# nos tickers mais valorizados 
lista_media = []
i=0
for i in range(quant_tickers):
  a = (dados[dados['Ticker']==lista_ordenada_media[i]['ticker']])
  lista_media.append(a.iloc[1, 11])
  i=+1

# separar os nomes dos setores em uma lista 
# e a quantidade de cada setor na outra lista

contagem_media = {}
for item in lista_media:
    if item in contagem_media:
        contagem_media[item] += 1
    else:
        contagem_media[item] = 1
quant = list(contagem_media.values())
setores = list(contagem_media.keys())


# Verificando os nomes das empresas

lista_nomes_media = []
i=0
for i in range(quant_tickers):
  b = (dados[dados['Nome']==lista_ordenada_media[i]['Nome']])
  lista_nomes_media.append(b.iloc[1, 10])
  i=+1

# separar os nomes das empresas em uma lista 
# e a quantidade que cada empresa aparece na lista

contagem = {}
for item in lista_nomes_media:
    if item in contagem:
        contagem_media[item] += 1
    else:
        contagem_media[item] = 1
quant_nome = list(contagem.values())
setores_nome = list(contagem.keys())

# plotando em um gráfico de barras horizontal 
#criando o gráfico
plt.barh(setores, quant)

# criando título do gráfico e legenda
plt.title("Setores das empresas com maiores médias")
plt.xlabel("Quantidade de ocorrencias ")
plt.ylabel("setor");

# %% [markdown]
#  Quando avaliamos os setores que os tickers tiveram valores médios mais elevados percebemos que, empresas do setor de utilidade pública tiveram o maior número seguida das empresas do setor financeiro é consumo cíclico.

# %% [markdown]
#  Com Base nos gráficos acima podemos chegar as seguintes  conclução:
#
# 1.   O setor das empresas que tiveram os maiores ganhos em suas ações no período avaliado foram:
#
#  1 - Bens industriais
#
#  2 - Financeiro
#
#  3 - Consumo cíclico
#
#  4 - Utilidade pública
#
#
# 2.   O setor das empresas que tiveram os maiores valores médiios nesse período foram:
#
#  1 - Utilidade pública
#
#  2 - Financeiro
#
#  3 - Consumo cíclico
#
#  Com base nessas informações a analise dos dados ficará restrita as empresas que tiveram os melhores resultados.

# %%
 # Veruficando os nomes dos itens em cada grupo, lista_nome_media
 # e listanomes_ganho

print('Empresas com maiores medias de valores ')
print(lista_nomes_media)
print('\nEmpresas com maiores ganhos ')
print(lista_nomes_ganho)

# Unindo os grupos retirando os tickers repetidos
finalistas = lista_nomes_media + lista_nomes_ganho

lista_unica = list(set(finalistas))
print('\nNúmero de tickers diferentes entre as empresas com maiores ganho e maiores valores médios')
print(len(lista_unica))
print('\nEmpresas com maiores medias de valores e ganhos ')
print(lista_unica)
# Out:
# Empresas com maiores medias de valores
# ['CEEE-GT', 'CEEE-GT', 'BIC MONARK', 'POLPAR', 'MONT ARANHA', 'MINASMAQUINA', 'METAL IGUACU', 'COMGAS', 'CONST A LIND', 'RIOSULENSE', 'GENERALSHOPP', 'BAHEMA', 'ENCORPAR', 'TEKNO', 'P.ACUCAR-CBD', 'COR RIBEIRO', 'MANGELS INDL', 'ENCORPAR', 'CEEE-D', 'TELEBRAS', 'CONST A LIND', 'ELETROPAR', 'CEEE-D', 'METALFRIO', 'NORD BRASIL', 'METAL IGUACU', 'COSAN', 'VALE', 'SPTURIS', 'B2W DIGITAL', 'AREZZO CO', 'CEB', 'PORTO SEGURO', 'COELCE', 'INTERMEDICA', 'BTGP BANCO', 'EXCELSIOR', 'DASA', 'PAR AL BAHIA', 'SEG AL BAHIA', 'SEG AL BAHIA', 'MELHOR SP', 'CELESC', 'PAR AL BAHIA', 'MELHOR SP', 'CEG', 'TELEF BRASIL', 'CELESC', 'SABESP', 'INVEST BEMGE']
#
# Empresas com maiores ganhos
# ['ODERICH', 'CEMEPE', 'BRB BANCO', 'SANSUY', 'IGB S/A', 'TAURUS ARMAS', 'INEPAR', 'BRB BANCO', 'TAURUS ARMAS', 'PETRORIO', 'MMX MINER', 'MAGAZ LUIZA', 'CEMEPE', 'EXCELSIOR', 'CEB', 'ACO ALTONA', 'GPC PART', 'PPLA', 'EMAE', 'RIOSULENSE', 'WLM IND COM', 'KARSTEN', 'BANCO PAN', 'TREVISA', 'DASA', 'BTGP BANCO', 'CELPE', 'KARSTEN', 'MERC FINANC', 'BTGP BANCO', 'ENERGISA MT', 'LOG-IN', 'ENEVA', 'DOHLER', 'TRISUL', 'CELGPAR', 'UNIPAR', 'ALPER S.A.', 'INTERMEDICA', 'MINUPAR', 'LUPATECH', 'WEG', 'SUZANO S.A.', 'SID NACIONAL', 'PANATLANTICA', 'CEEE-GT', 'JHSF PART', 'TEKA', 'INDS ROMI', 'MERC BRASIL']
#
# Número de tickers diferentes entre as empresas com maiores ganho e maiores valores médios
# 79
#
# Empresas com maiores medias de valores e ganhos
# ['B2W DIGITAL', 'SUZANO S.A.', 'SABESP', 'MANGELS INDL', 'RIOSULENSE', 'JHSF PART', 'ACO ALTONA', 'TREVISA', 'DASA', 'COELCE', 'WEG', 'P.ACUCAR-CBD', 'INDS ROMI', 'EMAE', 'CEEE-GT', 'MMX MINER', 'COSAN', 'CEMEPE', 'MERC FINANC', 'GPC PART', 'BAHEMA', 'SANSUY', 'SPTURIS', 'POLPAR', 'GENERALSHOPP', 'METAL IGUACU', 'BANCO PAN', 'ENCORPAR', 'SID NACIONAL', 'PETRORIO', 'MINUPAR', 'CEB', 'KARSTEN', 'ENERGISA MT', 'CELGPAR', 'ODERICH', 'BTGP BANCO', 'DOHLER', 'CEEE-D', 'TRISUL', 'IGB S/A', 'TELEF BRASIL', 'BRB BANCO', 'TAURUS ARMAS', 'INEPAR', 'LUPATECH', 'AREZZO CO', 'NORD BRASIL', 'INTERMEDICA', 'VALE', 'TELEBRAS', 'MINASMAQUINA', 'TEKA', 'EXCELSIOR', 'ALPER S.A.', 'COR RIBEIRO', 'CELPE', 'LOG-IN', 'CEG', 'ELETROPAR', 'PORTO SEGURO', 'PAR AL BAHIA', 'MERC BRASIL', 'METALFRIO', 'TEKNO', 'BIC MONARK', 'MONT ARANHA', 'SEG AL BAHIA', 'WLM IND COM', 'ENEVA', 'PANATLANTICA', 'UNIPAR', 'INVEST BEMGE', 'COMGAS', 'CELESC', 'MELHOR SP', 'CONST A LIND', 'PPLA', 'MAGAZ LUIZA']

# %% [markdown]
#  Verificando os tickers que tiveram maiores valores médios e maiores ganhos, temos um total de 79 tickers, para avalizar quais ações tem as melhores chances de continuar peformando bem a analíse se restrigirá as empresas dos melhores setores.
#
#  Seno esses setores :
# 1.   Bens industriais
# 2.   Financeiro
# 3.   Consumo cíclico
# 4.   Utilidade pública

# %%
Bens_industriais = []
Financeiro = []
Consumo_cilico = []
Utilidade_publica = []

i = 0
for nome in lista_unica:
  a = (dados[dados['Nome']==lista_unica[i]])
  i= i + 1

  if a.iloc[0,11] == 'Bens Industriais':
    Bens_industriais.append(a.iloc[0,7])
  elif a.iloc[0,11] == 'Financeiro':
    Financeiro.append(a.iloc[0,7])
  elif a.iloc[0,11] == 'Consumo Cíclico':
    Consumo_cilico.append(a.iloc[0,7])
  elif a.iloc[0,11] == 'Utilidade Pública':
    Utilidade_publica.append(a.iloc[0,7])
 
print(' Tickers do setor bens industriais ')    
print('Quantidade de empresas {}'.format(len(Bens_industriais)))
print(Bens_industriais)
print('\n Tickers do setor Financeiro ')
print('Quantidade de empresas {}'.format(len(Financeiro)))
print(Financeiro)
print(' \nTickers do setor Consumo_cilico ') 
print('Quantidade de empresas {}'.format(len(Consumo_cilico)))
print(Consumo_cilico)
print(' \nTickers de Utilidade_publica ') 
print('Quantidade de empresas {}'.format(len(Utilidade_publica)))
print(Utilidade_publica)
# Out:
#  Tickers do setor bens industriais
# Quantidade de empresas 11
# ['RSUL4.SA', 'EALT3.SA', 'LUXM3.SA', 'WEGE3.SA', 'ROMI3.SA', 'TASA3.SA', 'INEP4.SA', 'MMAQ3.SA', 'LOGN3.SA', 'FRIO3.SA', 'WLMM3.SA']
#
#  Tickers do setor Financeiro
# Quantidade de empresas 15
# ['MERC3.SA', 'GSHP3.SA', 'BPAN4.SA', 'BPAC3.SA', 'IGBR3.SA', 'BSLI3.SA', 'BNBR3.SA', 'APER3.SA', 'CORR3.SA', 'PSSA3.SA', 'PEAB3.SA', 'BMEB3.SA', 'MOAR3.SA', 'CSAB3.SA', 'PPLA11.SA']
#
# Tickers do setor Consumo_cilico
# Quantidade de empresas 13
# ['BTOW3.SA', 'JHSF3.SA', 'BAHI3.SA', 'AHEB3.SA', 'ECPR3.SA', 'CTKA3.SA', 'DOHL3.SA', 'TRIS3.SA', 'ARZZ3.SA', 'TEKA3.SA', 'BMKS3.SA', 'CALI3.SA', 'MGLU3.SA']
#
# Tickers de Utilidade_publica
# Quantidade de empresas 14
# ['SBSP3.SA', 'COCE3.SA', 'EMAE4.SA', 'EEEL3.SA', 'CEBR3.SA', 'ENMT3.SA', 'GPAR3.SA', 'CEED3.SA', 'CEPE3.SA', 'CEGR3.SA', 'LIPR3.SA', 'ENEV3.SA', 'CGAS3.SA', 'CLSC3.SA']

# %% [markdown]
# # Gráficos dos tickers

# %% [markdown]
#  Gráficos dos tickers do setor de Bens industriais

# %%
import numpy as np
import seaborn as sns
legenda = []
i=0
t = np.arange(0., 796, 1)
plt.figure(figsize = (10,8))
for nomes in Bens_industriais:
  legenda.append(Bens_industriais[i])
  a=((dados[dados['Ticker']==Bens_industriais[i]]).iloc[0:len(dados['Ticker']), 3:4])
  t = np.arange(0.,len(a), 1)
  plt.plot(t, a)
  i+=1
plt.title('Valor das ações Bens Industriais')
plt.legend(legenda,fontsize = 10, loc='upper left');
plt.xlabel('Dias de pregão ', fontsize = 12)
plt.ylabel('Valor da ação R$', fontsize = 12)
plt.show()

# %% [markdown]
#  Avaliando o resultado do gráficos acima percebemos que:
#
#
#
# 1.   Os ticker que tiveram os maiores valor no final do período de analíse foram o WLMM3.SA, FRIO3.SA E WEGE3.SA.
#
# 2.   É possível perceber que por volta do pregão 580 as princiais empresas sofreram uma baixa nos valores das ações.

# %% [markdown]
# Gráficos dos tickers do Setor financeiro

# %%
legenda = []
i=0
t = np.arange(0., 796, 1)
plt.figure(figsize = (10,8))
for nomes in Financeiro:
  legenda.append(Financeiro[i])
  a=((dados[dados['Ticker']==Financeiro[i]]).iloc[0:len(dados['Ticker']), 3:4])
  t = np.arange(0.,len(a), 1)
  plt.plot(t, a)
  i+=1
plt.title('Valor das ações do setor Financeiro')
plt.legend(legenda,fontsize = 10, loc='upper left');
plt.xlabel('Dias de pregão ', fontsize = 12)
plt.ylabel('Valor da ação R$', fontsize = 12)
plt.show()

# %% [markdown]
#  No gráfico acima é possível perceber que os valores da ação BPAN4.SA tiveram em alguns dias valores que não são compativel com o comportamento das ações, esse comportamento indica erro de coleta dos dados.
#  Pesquisando em sites especializados no assunto podemos ver que esses dados realmente estão errados.
#  ![Capturar.JPG](data:image/jpeg;base64,...)
#
#  Fonte : https://www.infomoney.com.br/cotacoes/b3/acao/banco-pan-bpan4/grafico/
#  data de acesso 29 de abril 2023.
#
#   Por isso os valores nesses dias serão desconsiderados.

# %%
# Gráfico com os valores das ações desconsiderando os valores com erros 

legenda = []
i=0
t = np.arange(0., 796, 1)
plt.figure(figsize = (10,8))
for nomes in Financeiro:
  legenda.append(Financeiro[i])
  a=((dados[dados['Ticker']==Financeiro[i]]).iloc[0:len(dados['Ticker']), 3:4])
  t = np.arange(0.,len(a), 1)
  plt.plot(t, a)
  i+=1
plt.title('Valor das ações do setor Financeiro')
plt.legend(legenda,fontsize = 10, loc='upper left');
plt.xlabel('Dias de pregão ', fontsize = 12)
plt.ylabel('Valor da ação R$', fontsize = 12)
plt.ylim(0,650)
plt.show()

# %% [markdown]
# Avaliando o resultado do gráficos acima percebemos que:
#
#
#
# 1.   Apenas um ticker se destaca positivamente nesse setor, o ticker MOAR3.SA.
#
# 2.   É possível perceber que por volta do pregão 580 a ação de destaque sofreu uma baixa no seu valor, como também foi observado no gráfico anterior.
#
# 3.   É possível observar um destaque negativo, a ação GSHP3.SA perdeu muito valor sendo uma escola ruim.

# %% [markdown]
# Gráficos dos tickers do Setor Consumo cilico

# %%
legenda = []
i=0
t = np.arange(0., 796, 1)
plt.figure(figsize = (10,8))
for nomes in Consumo_cilico:
  legenda.append(Consumo_cilico[i])
  a=((dados[dados['Ticker']==Consumo_cilico[i]]).iloc[0:len(dados['Ticker']), 3:4])
  t = np.arange(0.,len(a), 1)
  plt.plot(t, a)
  i+=1
plt.title('Valor das ações do setor Consumo_cilico')
plt.legend(legenda,fontsize = 10, loc='upper left');
plt.xlabel('Dias de pregão ', fontsize = 18)
plt.ylabel('Valor da ação R$', fontsize = 18)
plt.show()

# %% [markdown]
# Avaliando o resultado do gráficos acima percebemos que:
#
#
# 1.   Nesse setor os tickeres que se destacaram positivamente foram, TEKA3.SA, BTOW3.SA e ECPR3.SA.
#
# 2.   É possível perceber que por volta do pregão 580 as ações de destaque sofreram uma baixa nos seus valores, como também foi observado nos gráficos anteriores.
#
# 3.   É possível observar um destaque negativo, a ação BMKS3.SA perdeu muito valor sendo uma escola ruim.

# %% [markdown]
# Gráficos dos tickers do Setor Utilidade publica

# %%
legenda = []
i=0
t = np.arange(0., 796, 1)
plt.figure(figsize = (10,8))
for nomes in Utilidade_publica:
  legenda.append(Utilidade_publica[i])
  a=((dados[dados['Ticker']==Utilidade_publica[i]]).iloc[0:len(dados['Ticker']), 3:4])
  t = np.arange(0.,len(a), 1)
  plt.plot(t, a)
  i+=1
plt.title('Valor das ações do setor Utilidade publica')
plt.legend(legenda,fontsize = 10);
plt.xlabel('Dias de pregão ', fontsize = 18)
plt.ylabel('Valor da ação R$', fontsize = 18)
plt.show()

# %% [markdown]
# valiando o resultado do gráficos acima percebemos que:
#
#
# 1.   Nesse setor os tickeres que se destacaram positivamente foram, EEEL3.SA, CGAS3.SA e CEBR3.SA.
#
# 2.   É possível perceber que por volta do pregão 580 as ações de destaque sofreram uma baixa nos seus valores, como também foi observado nos gráficos anteriores.

# %% [markdown]
#  Conclusão

# %% [markdown]
#  Baseado nos gráficos acima podemos perceber que:
#
#
# 1.    As melhores ações para investir com base no crescimento do valor das ações foram:
#
# *   No setor de Utilidade pública:
#
# EEEL3.SA
#
# CGAS3.SA
#
# CEBR3.SA
#
# *   No setor de Consumo cilico
#
# TEKA3.SA
#
# BTOW3.SA
#
# ECPR3.SA.
#
#
# *   setor Financeiro
#
# MOAR3.SA
#
#
# *   Bens industriais
#
# WLMM3.SA
#
# FRIO3.SA
#
# WEGE3.SA
#
#
#
# 2.   Podemos perceber que entre os pregões de N° 580 a 600 em torno da data 25 de maio de 2018 a 06 de junho de 2018 as empresas de destaque perderam valor de mercado.
#  Procurando notícias sobre esse período na internet encontramos:
#  ![Capturar2.JPG](data:image/jpeg;base64,...)
#
#
#    O que está de acordo com os dados do dataframe
